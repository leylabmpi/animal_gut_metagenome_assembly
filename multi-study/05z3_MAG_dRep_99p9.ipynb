# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Project-list" data-toc-modified-id="Project-list-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Project list</a></span></li><li><span><a href="#Project-metadata" data-toc-modified-id="Project-metadata-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Project metadata</a></span></li><li><span><a href="#Collecting-all-MAGs" data-toc-modified-id="Collecting-all-MAGs-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Collecting all MAGs</a></span><ul class="toc-item"><li><span><a href="#Checkm-info-for-dRep" data-toc-modified-id="Checkm-info-for-dRep-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Checkm info for dRep</a></span></li><li><span><a href="#Quality-MAGs-per-sample" data-toc-modified-id="Quality-MAGs-per-sample-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Quality MAGs per sample</a></span><ul class="toc-item"><li><span><a href="#checkM" data-toc-modified-id="checkM-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>checkM</a></span></li></ul></li></ul></li><li><span><a href="#dRep" data-toc-modified-id="dRep-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>dRep</a></span><ul class="toc-item"><li><span><a href="#Results" data-toc-modified-id="Results-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Adding-info" data-toc-modified-id="Adding-info-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Adding info</a></span><ul class="toc-item"><li><span><a href="#checkM" data-toc-modified-id="checkM-7.1.1.1"><span class="toc-item-num">7.1.1.1&nbsp;&nbsp;</span>checkM</a></span></li><li><span><a href="#gtdbtk" data-toc-modified-id="gtdbtk-7.1.1.2"><span class="toc-item-num">7.1.1.2&nbsp;&nbsp;</span>gtdbtk</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#checkM" data-toc-modified-id="checkM-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>checkM</a></span></li><li><span><a href="#GTDBTk" data-toc-modified-id="GTDBTk-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>GTDBTk</a></span></li></ul></li><li><span><a href="#Summary-by-project" data-toc-modified-id="Summary-by-project-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Summary by project</a></span><ul class="toc-item"><li><span><a href="#GTDBTk" data-toc-modified-id="GTDBTk-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>GTDBTk</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * dreplicate all MAGs at 99.9 % ANI

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/'
MAG_dir = file.path(work_dir, 'MAGs')
tmp_out_dir = '/ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/'

# project metadata
study_meta_file = '/ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/metadata/study_metadata_v2.xlsx'

# params
threads = 24
ani = 0.999
conda_env = 'metacompass'

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(readxl)
library(ggplot2)
library(data.table)
library(doParallel)

library(future)
library(future.batchtools)
library(future.apply)
options(future.wait.interval = 2.0)

source('/ebio/abt3_projects/Georg_animal_feces/code/misc_r_functions/init.R')
dt.dims(4,20)

# %%
make_dir(MAG_dir)
cat('\n')
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs

# %% [markdown]
# # Project list

# %%
projects = dir(tmp_out_dir, 'PR*', full.names = TRUE) %>% sapply(basename) %>% as.vector
projects %>% length %>% print
projects
# Out:
# [1] 13
#  [1] "PRJEB11755"              "PRJEB20308"
#  [3] "PRJEB22765"              "PRJEB23642"
#  [5] "PRJEB29346"              "PRJEB9357"
#  [7] "PRJNA316560-PRJNA316570" "PRJNA336354"
#  [9] "PRJNA381379"             "PRJNA417359"
# [11] "PRJNA476660"             "PRJNA485217"
# [13] "PRJNA532626"

# %% [markdown]
# # Project metadata

# %%
study_meta = readxl::read_excel(study_meta_file)
study_meta %>% dfhead
# Out:
# [1] 13  4
#   ProjectID  Host    Num_samples_used Publication_DOI
# 1 PRJEB11755 Pig     100              DOI: 10.1038/nmicrobiol.2016.161
# 2 PRJEB20308 Dog     100              DOI: 10.1186/s40168-018-0450-3
# 3 PRJEB22765 Macaque  20              DOI: 10.1093/gigascience/giy100

# %%
# checking overlap
intersect(projects, study_meta$ProjectID) %>% length
# Out:
# [1] 13

# %% [markdown]
# # Collecting all MAGs
#
# * combining all MAGs in 1 directory; renaming as needed
# * all MAGs generated

# %%
# MAGs selected by DAS-tool 
das_tool_genomes = function(projectID, tmp_out_dir){
    asmbl_dir = out_dir = file.path(tmp_out_dir, projectID, 'LLMGA')
    das_tool_dir = file.path(asmbl_dir, 'bin_refine', 'DAS_Tool')
    
    dastool_files = list.files(das_tool_dir, '*.fa$', full.names=TRUE, recursive=TRUE)
    dastool = data.frame(binID = gsub('\\.fa$', '', basename(dastool_files)),
                    fasta = dastool_files)
    dastool$projectID = projectID
    return(dastool)
}

# loading all post das-tool files
dastool = projects %>% as.list %>% lapply(das_tool_genomes, tmp_out_dir=tmp_out_dir) %>%
    do.call(rbind, .)
dastool %>% dfhead
# Out:
# [1] 8488    3
#   binID
# 1 SAMEA3663006__maxbin2_high_prob.014.contigs
# 2 SAMEA3663006__maxbin2_low_prob.005.contigs
# 3 SAMEA3663006__metabat2_high_PE.015.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__maxbin2_high_prob.014.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__maxbin2_low_prob.005.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__metabat2_high_PE.015.contigs.fa
#   projectID
# 1 PRJEB11755
# 2 PRJEB11755
# 3 PRJEB11755

# %%
# checking for unique naming 
dastool$binID %>% length %>% print
dastool$binID %>% unique %>% length %>% print
# Out:
# [1] 8488
# [1] 8488

# %%
# copying MAGs
dastool = dastool %>%
    mutate(out_file = gsub('.+/', paste0(MAG_dir, '/'), fasta)) 
dastool %>% dfhead
# Out:
# [1] 8488    4
#   binID
# 1 SAMEA3663006__maxbin2_high_prob.014.contigs
# 2 SAMEA3663006__maxbin2_low_prob.005.contigs
# 3 SAMEA3663006__metabat2_high_PE.015.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__maxbin2_high_prob.014.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__maxbin2_low_prob.005.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663006__metabat2_high_PE.015.contigs.fa
#   projectID
# 1 PRJEB11755
# 2 PRJEB11755
# 3 PRJEB11755
#   out_file
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663006__maxbin2_high_prob.014.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663006__maxbin2_low_prob.005.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663006__metabat2_high_PE.015.contigs.fa

# %%
# copying MAGs 
cp_files = function(src, dst){
     file.copy(as.character(src), as.character(dst))
}

res = mapply(cp_files, dastool$fasta, dastool$out_file)

# %%
# checking number of fasta files copied
F = list.files(MAG_dir) 
F = F[grepl('.fa$', F)]
F %>% length %>% print
# Out:
# [1] 8488

# %% [markdown]
# ## Checkm info for dRep

# %%
checkm_info = function(projectID, tmp_out_dir){
    asmbl_dir = out_dir = file.path(tmp_out_dir, projectID, 'LLMGA')
    checkm_markers_file = file.path(asmbl_dir, 'checkm', 'markers_qa_summary.tsv')
    
    markers_sum = read.delim(checkm_markers_file, sep='\t')

    markers_sum$projectID = projectID
    return(markers_sum)
}

# checkm info
markers_sum = projects %>% as.list %>% lapply(checkm_info, tmp_out_dir=tmp_out_dir) %>%
    do.call(rbind, .) %>%
    inner_join(dastool, c('Bin.Id'='binID', 'projectID'='projectID'))
markers_sum %>% dfhead
# Out:
# [1] 8488   32
#   Bin.Id                                     Marker.lineage
# 1 SAMEA3663136__maxbin2_low_prob.001.contigs o__Bacteroidales (UID2716)
# 2 SAMEA3663136__maxbin2_low_prob.002.contigs c__Clostridia (UID1118)
# 3 SAMEA3663136__maxbin2_low_prob.008.contigs o__Bacteroidales (UID2617)
#   X..genomes X..markers X..marker.sets Completeness Contamination
# 1  92        487        270            69.20        1.20
# 2 387        223        124            36.76        0.00
# 3 213        406        265            80.57        0.89
#   Strain.heterogeneity Genome.size..bp. X..ambiguous.bases ⋯ X..predicted.genes
# 1 36.36                2021688          0                  ⋯ 2269
# 2  0.00                 559857          0                  ⋯  736
# 3 60.00                2026627          0                  ⋯ 2016
#   X0  X1  X2 X3 X4 X5. projectID
# 1 134 342 11 0  0  0   PRJEB11755
# 2 136  87  0 0  0  0   PRJEB11755
# 3  64 337  5 0  0  0   PRJEB11755
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663136__maxbin2_low_prob.001.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663136__maxbin2_low_prob.002.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJEB11755/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/SAMEA3663136__maxbin2_low_prob.008.contigs.fa
#   out_file
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663136__maxbin2_low_prob.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663136__maxbin2_low_prob.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/SAMEA3663136__maxbin2_low_prob.008.contigs.fa

# %%
markers_sum$Completeness %>% summary %>% print
markers_sum$Completeness %>% sd %>% print
markers_sum$Contamination %>% summary %>% print
markers_sum$Contamination %>% sd %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.52   70.05   88.75   80.12   96.13  100.00
# [1] 20.94155
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.430   1.100   2.373   2.100 111.520
# [1] 6.289622

# %%
n_quality_MAGs = markers_sum %>%
    filter(Completeness >= 50,
           Contamination < 5) %>%
    nrow

cat('Number of quality MAGs:', n_quality_MAGs, '\n')
# Out:
# Number of quality MAGs: 6939

# %%
# writing table of checkm info for dRep
markers_sum_f = markers_sum %>%
    dplyr::select(out_file, Completeness, Contamination) %>%
    mutate(out_file = gsub('\\/+', '\\/', out_file)) %>%
    rename('genome' = out_file,
           'completeness' = Completeness,
           'contamination' = Contamination) %>%
    mutate(completeness = completeness %>% as.character %>% as.numeric,
           completeness = ifelse(is.na(completeness), 0, completeness),
           contamination = contamination %>% as.character %>% as.numeric,
           contamination = ifelse(is.na(contamination), 0, contamination))

checkm_info_F = file.path(MAG_dir, 'checkm_info.tsv')
markers_sum_f %>%
    write.table(file=checkm_info_F, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', checkm_info_F, '\n')
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/checkm_info.tsv

# %% [markdown]
# ## Quality MAGs per sample

# %%
# summarizing quality MAGs
markers_sum_s = markers_sum %>%
    filter(Completeness >= 50,
           Contamination < 5) %>%
    group_by(projectID) %>%
    summarize(n_MAGs = n()) %>%
    ungroup() %>%
    inner_join(study_meta, c('projectID'='ProjectID')) 

markers_sum_s$n_MAGs %>% summary %>% print
markers_sum_s$n_MAGs %>% sd %>% print

markers_sum_s
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0    29.0   128.0   533.8  1152.0  1885.0
# [1] 646.4931
#    projectID   n_MAGs Host             Num_samples_used
# 1  PRJEB11755  1152   Pig              100
# 2  PRJEB20308  1885   Dog              100
# ⋮  ⋮           ⋮      ⋮                ⋮
# 12 PRJNA485217 128    Capuchin         19
# 13 PRJNA532626 548    Black rhinoceros 25
#    Publication_DOI
# 1  DOI: 10.1038/nmicrobiol.2016.161
# 2  DOI: 10.1186/s40168-018-0450-3
# ⋮  ⋮
# 12 DOI: 10.1038/s41396-018-0256-0
# 13 DOI: 10.1038/s41598-019-43875-3

# %%
# plotting
p = markers_sum_s %>%
    ggplot(aes(projectID, n_MAGs, fill=Host)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=n_MAGs), 
              size=2, vjust=-0.16) +
    geom_text(aes(y=0, label=Num_samples_used), 
              size=2, vjust=1.5) +
    scale_y_continuous(limits=c(-100, 1900)) +
    labs(x='BioProject', y='No. of MAGs') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1),
        axis.title.x = element_blank(),
        legend.position = 'top',
        legend.text=element_text(size=7),
        legend.title=element_text(size=7)
    )

dims(5,4.2,res=150)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### checkM

# %%
markers_sum_s = markers_sum %>%
    filter(Completeness >= 50,
           Contamination < 5) 

markers_sum_s$Completeness %>% summary %>% print
markers_sum_s$Completeness %>% sd %>% print
markers_sum_s$Contamination %>% summary %>% print
markers_sum_s$Contamination %>% sd %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   50.08   78.60   91.39   86.24   96.63  100.00
# [1] 13.18164
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.500   1.080   1.294   1.900   4.990
# [1] 1.070386

# %%
markers_sum_s = markers_sum %>%
    filter(Completeness >= 50,
           Contamination < 5) %>%
    dplyr::select(projectID, Completeness, Contamination) %>%
    gather(checkm_metric, checkm_value, -projectID) %>%
    inner_join(study_meta, c('projectID'='ProjectID')) 

markers_sum_s
# Out:
#       projectID   checkm_metric checkm_value Host             Num_samples_used
# 1     PRJEB11755  Completeness  69.20        Pig              100
# 2     PRJEB11755  Completeness  80.57        Pig              100
# ⋮     ⋮           ⋮             ⋮            ⋮                ⋮
# 13877 PRJNA532626 Contamination 0.67         Black rhinoceros 25
# 13878 PRJNA532626 Contamination 1.42         Black rhinoceros 25
#       Publication_DOI
# 1     DOI: 10.1038/nmicrobiol.2016.161
# 2     DOI: 10.1038/nmicrobiol.2016.161
# ⋮     ⋮
# 13877 DOI: 10.1038/s41598-019-43875-3
# 13878 DOI: 10.1038/s41598-019-43875-3

# %%
p = markers_sum_s %>%
    ggplot(aes(projectID, checkm_value, color=Host)) +
    geom_boxplot() +
    facet_grid(checkm_metric ~ ., scales='free_y') +
    labs(x='BioProject', y='') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1),
        axis.title.x = element_blank(),
        legend.position = 'top',
        legend.text=element_text(size=7),
        legend.title=element_text(size=7)
    )

dims(5,4.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # dRep

# %%
# output directory (deletes if exists)
drep_outdir = file.path(MAG_dir, 'drep_99p9')
unlink(drep_outdir, recursive = TRUE)
make_dir(drep_outdir)
# Out:
# Created directory: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9

# %%
# data_tables directory (for Bdb.csv)
drep_dt_outdir = file.path(drep_outdir, 'data_tables')
make_dir(drep_dt_outdir)
# Out:
# Created directory: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/data_tables

# %%
# creating a file with genome info for dRep
bdb_F = file.path(drep_dt_outdir, 'Bdb.csv')
markers_sum %>%
    mutate(genome = basename(out_file)) %>%
    rename('location' = out_file,
           'length' = Genome.size..bp.) %>%
    dplyr::select(genome, location, length) %>%
    write.table(file=bdb_F, sep=',', quote=FALSE, row.names=FALSE)
cat('File written:', bdb_F, '\n')
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/data_tables/Bdb.csv

# %%
# dRep cmd
cmd = 'dRep dereplicate -comp 50 -con 5 -sa {ani} -p {threads} --genomeInfo {checkm_info} {outdir}'
cmd = glue::glue(cmd, threads=threads, ani=ani, checkm_info=checkm_info_F, outdir=drep_outdir)
cmd
# Out:
# dRep dereplicate -comp 50 -con 5 -sa 0.999 -p 24 --genomeInfo /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/checkm_info.tsv /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9

# %%
# local run (relatively short job due to providing checkm info)
bash_job(cmd, conda_env=conda_env)
# Out:
#   [1] "***************************************************"
#   [2] "    ..:: dRep dereplicate Step 1. Filter ::.."
#   [3] "***************************************************"
#   [4] "    "
#   [5] "Will filter Bdb"
#   [6] "Calculating genome info of genomes"
#   [7] "99.99% of genomes passed length filtering"
#   [8] "Provided genome info has full genome path- correcting"
#   [9] "81.77% of genomes passed checkM filtering"
#  [10] "***************************************************"
#  [11] "    ..:: dRep dereplicate Step 2. Cluster ::.."
#  [12] "***************************************************"
#  [13] "    "
#  [14] "Clustering Step 1. Parse Arguments"
#  [15] "Clustering Step 2. Perform MASH (primary) clustering"
#  [16] "2a. Run pair-wise MASH clustering"
#  [17] "2b. Cluster pair-wise MASH clustering"
#  [18] "1258 primary clusters made"
#  [19] "Step 3. Perform secondary clustering"
#  [20] "Running 220660 ANImf comparisons- should take ~ 4597.1 min"
#  [21] "Step 4. Return output"
#  [22] "***************************************************"
#  [23] "    ..:: dRep dereplicate Step 3. Choose ::.."
#  [24] "***************************************************"
#  [25] "    "
#  [26] "Loading work directory"
#  [27] "Provided genome info has full genome path- correcting"
#  [28] "***************************************************"
#  [29] "    ..:: dRep dereplicate Step 4. Bonus ::.."
#  [30] "***************************************************"
#  [31] "    "
#  [32] "Loading work directory"
#  [33] "***************************************************"
#  [34] "    ..:: dRep dereplicate Step 5. Evaluate ::.."
#  [35] "***************************************************"
#  [36] "    "
#  [37] "will provide warnings about clusters"
#  [38] "3814 warnings generated: saved to /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9/log/warnings.txt"
#  [39] "will produce Widb (winner information db)"
#  [40] "Winner database saved to /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9data_tables/Widb.csv"
#  [41] "***************************************************"
#  [42] "    ..:: dRep dereplicate Step 6. Analyze ::.."
#  [43] "***************************************************"
#  [44] "    "
#  [45] "making plots 1, 2, 3, 4, 5, 6"
#  [46] "Plotting primary dendrogram"
#  [47] "Failed to make plot #1: Image size of 1000x138800 pixels is too large. It must be less than 2^16 in each direction."
#  [48] "Traceback (most recent call last):"
#  [49] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 62, in d_analyze_wrapper"
#  [50] "    mash_dendrogram_from_wd(wd, plot_dir=plot_dir)"
#  [51] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 136, in mash_dendrogram_from_wd"
#  [52] "    plot_dir = plot_dir)"
#  [53] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 649, in plot_MASH_dendrogram"
#  [54] "    format=\"pdf\", transparent=True, bbox_inches='tight')"
#  [55] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/matplotlib/pyplot.py\", line 711, in savefig"
#  [56] "    fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors"
#  [57] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/matplotlib/backend_bases.py\", line 2055, in draw_idle"
#  [58] "    self.draw(*args, **kwargs)"
#  [59] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py\", line 425, in draw"
#  [60] "    self.renderer = self.get_renderer(cleared=True)"
#  [61] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py\", line 450, in get_renderer"
#  [62] "    self.renderer = RendererAgg(w, h, self.figure.dpi)"
#  [63] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py\", line 97, in __init__"
#  [64] "    self._renderer = _RendererAgg(int(width), int(height), dpi)"
#  [65] "ValueError: Image size of 1000x138800 pixels is too large. It must be less than 2^16 in each direction."
#  [66] "Plotting secondary dendrograms"
#  [67] "Plotting MDS plot"
#  [68] "Plotting scatterplots"
#  [69] "/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result."
#  [70] "  return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval"
#  [71] "Plotting bin scorring plot"
#  [72] "Failed to make plot #5: Neither the `x` nor `y` variable appears to be numeric."
#  [73] "Traceback (most recent call last):"
#  [74] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 94, in d_analyze_wrapper"
#  [75] "    plot_binscoring_from_wd(wd, plot_dir, **kwargs)"
#  [76] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 344, in plot_binscoring_from_wd"
#  [77] "    plot_winner_scoring_complex(Wdb, Sdb, Cdb, Gdb, plot_dir = plot_dir, **kwargs)"
#  [78] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 698, in plot_winner_scoring_complex"
#  [79] "    g = sns.barplot(data=db, y='genome', x='value', hue='variable')"
#  [80] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 3149, in barplot"
#  [81] "    errcolor, errwidth, capsize, dodge)"
#  [82] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 1607, in __init__"
#  [83] "    order, hue_order, units)"
#  [84] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 158, in establish_variables"
#  [85] "    orient = self.infer_orient(x, y, orient)"
#  [86] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 361, in infer_orient"
#  [87] "    raise ValueError(no_numeric)"
#  [88] "ValueError: Neither the `x` nor `y` variable appears to be numeric."
#  [89] "Plotting winning genomes plot..."
#  [90] "Failed to make plot #6: Neither the `x` nor `y` variable appears to be numeric."
#  [91] "Traceback (most recent call last):"
#  [92] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 102, in d_analyze_wrapper"
#  [93] "    plot_winners_from_wd(wd, plot_dir, **kwargs)"
#  [94] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 378, in plot_winners_from_wd"
#  [95] "    plot_winners(Wdb, Gdb, Wndb, Wmdb, Widb, plot_dir = plot_dir, **kwargs)"
#  [96] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 815, in plot_winners"
#  [97] "    _make_scoring_plot(d,bars,**kwargs)"
#  [98] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/drep/d_analyze.py\", line 1345, in _make_scoring_plot"
#  [99] "    g = sns.barplot(data=d, y='genome', x='value', hue='variable')"
# [100] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 3149, in barplot"
# [101] "    errcolor, errwidth, capsize, dodge)"
# [102] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 1607, in __init__"
# [103] "    order, hue_order, units)"
# [104] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 158, in establish_variables"
# [105] "    orient = self.infer_orient(x, y, orient)"
# [106] "  File \"/ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass/lib/python3.6/site-packages/seaborn/categorical.py\", line 361, in infer_orient"
# [107] "    raise ValueError(no_numeric)"
# [108] "ValueError: Neither the `x` nor `y` variable appears to be numeric."
# [109] ""
# [110] "$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$"
# [111] ""
# [112] "    ..:: dRep dereplicate finished ::.."
# [113] ""
# [114] "Dereplicated genomes................. /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9/dereplicated_genomes/"
# [115] "Dereplicated genomes information..... /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9/data_tables/Widb.csv"
# [116] "Figures.............................. /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9/figures/"
# [117] "Warnings............................. /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA/MAGs/drep_99p9/log/warnings.txt"
# [118] ""
# [119] "$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$"
# [120] "    "

# %% [markdown]
# ## Results

# %%
# number of dereplicated genomes
drep_fna_files = list.files(file.path(drep_outdir, 'dereplicated_genomes'), '*.fa', full.names=TRUE)
cat('Number of dreplicated genomes:', drep_fna_files %>% length, '\n')
# Out:
# Number of dreplicated genomes: 5301

# %%
# dataframe of selected genomes
drep_res = data.frame(binID = gsub('\\.fa$', '', basename(drep_fna_files)),
                      fasta = drep_fna_files)

drep_res %>% dfhead
# Out:
# [1] 5301    2
#   binID
# 1 artificially_reared_1__metabat2_low_PE.001.contigs
# 2 artificially_reared_1__metabat2_low_PE.002.contigs
# 3 artificially_reared_1__metabat2_low_PE.008.contigs
#   fasta
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.008.contigs.fa

# %% [markdown]
# ### Adding info

# %% [markdown]
# #### checkM

# %%
# adding checkm info
drep_res_j = drep_res %>%
    inner_join(markers_sum, c('binID'='Bin.Id'))

drep_res_j %>% dfhead
# Out:
# Warning message:
# “Column `binID`/`Bin.Id` joining factors with different levels, coercing to character vector”
# [1] 5301   33
#   binID
# 1 artificially_reared_1__metabat2_low_PE.001.contigs
# 2 artificially_reared_1__metabat2_low_PE.002.contigs
# 3 artificially_reared_1__metabat2_low_PE.008.contigs
#   fasta.x
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.008.contigs.fa
#   Marker.lineage              X..genomes X..markers X..marker.sets Completeness
# 1 o__Bacteroidales (UID2657)  160        491        268            87.24
# 2 o__Bacteroidales (UID2657)  160        491        268            92.92
# 3 o__Lactobacillales (UID543) 294        472        265            97.74
#   Contamination Strain.heterogeneity Genome.size..bp. ⋯ X..predicted.genes X0
# 1 4.15          45.00                2455242          ⋯ 2295               60
# 2 3.00          28.57                3388189          ⋯ 2909               39
# 3 1.73          33.33                2072345          ⋯ 2033               12
#   X1  X2 X3 X4 X5. projectID
# 1 411 20 0  0  0   PRJNA316560-PRJNA316570
# 2 438 14 0  0  0   PRJNA316560-PRJNA316570
# 3 454  6 0  0  0   PRJNA316560-PRJNA316570
#   fasta.y
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA316560-PRJNA316570/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA316560-PRJNA316570/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA316560-PRJNA316570/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/artificially_reared_1__metabat2_low_PE.008.contigs.fa
#   out_file
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/artificially_reared_1__metabat2_low_PE.008.contigs.fa

# %% [markdown]
# #### gtdbtk

# %%
gtdbtk_info = function(projectID, tmp_out_dir){
    asmbl_dir = out_dir = file.path(tmp_out_dir, projectID, 'LLMGA')
    gtdbtk_bac_sum_file = file.path(asmbl_dir, 'gtdbtk', 'gtdbtk_bac_summary.tsv')
    gtdbtk_arc_sum_file = file.path(asmbl_dir, 'gtdbtk', 'gtdbtk_ar_summary.tsv')

    ## bacteria
    gtdb = read.delim(gtdbtk_bac_sum_file, sep='\t') %>%
        dplyr::select(-other_related_references.genome_id.species_name.radius.ANI.AF.) %>%
        separate(classification, c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'), sep=';')
    ## archaea
    if(file.size(gtdbtk_arc_sum_file) > 0){
        X = read.delim(gtdbtk_arc_sum_file, sep='\t', header=FALSE) 
        colnames(X) = gtdbtk_bac_sum_file %>% read.delim(sep='\t') %>% colnames
        X = X %>%
            dplyr::select(-other_related_references.genome_id.species_name.radius.ANI.AF.) %>%
            separate(classification, c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'), sep=';')
        gtdb = rbind(gtdb,X)
    }
    gtdb$projectID = projectID
    return(gtdb)
}

# gtdb info
gtdb = projects %>% as.list %>% lapply(gtdbtk_info, tmp_out_dir=tmp_out_dir) %>%
    do.call(rbind, .)
gtdb %>% dfhead
# Out:
# Warning message:
# “Expected 7 pieces. Missing pieces filled with `NA` in 1 rows [1].”Warning message:
# “Expected 7 pieces. Missing pieces filled with `NA` in 1 rows [1].”Warning message in `[<-.factor`(`*tmp*`, ri, value = c(0.912633214467, 0.908236779677, :
# “invalid factor level, NA generated”Warning message in `[<-.factor`(`*tmp*`, ri, value = c(0.949860619467, 0.854655634167, :
# “invalid factor level, NA generated”
# [1] 8490   25
#   user_genome                                Domain      Phylum
# 1 SAMEA3663177__metabat2_low_PE.009.contigs  d__Bacteria p__Bacteroidota
# 2 SAMEA3663136__metabat2_low_PE.004.contigs  d__Bacteria p__Firmicutes_C
# 3 SAMEA3663177__metabat2_high_PE.004.contigs d__Bacteria p__Firmicutes_C
#   Class            Order                Family
# 1 c__Bacteroidia   o__Bacteroidales     f__Bacteroidaceae
# 2 c__Negativicutes o__Acidaminococcales f__Acidaminococcaceae
# 3 c__Negativicutes o__Veillonellales    f__Dialisteraceae
#   Genus                      Species
# 1 g__Prevotella              s__Prevotella sp000834015
# 2 g__Phascolarctobacterium_A s__Phascolarctobacterium_A succinatutens
# 3 g__Dialister               s__Dialister sp000434475
#   fastani_reference fastani_reference_radius ⋯ closest_placement_ani
# 1 GCF_000834015.1   95.0                     ⋯ 99.21
# 2 GCF_000188175.1   95.0                     ⋯ 99.52
# 3 GCA_000434475.1   95.0                     ⋯ 96.55
#   closest_placement_af
# 1 0.98
# 2 1.0
# 3 0.96
#   pplacer_taxonomy
# 1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Prevotella;s__
# 2 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Acidaminococcales;f__Acidaminococcaceae;g__Phascolarctobacterium_A;s__
# 3 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales;f__Dialisteraceae;g__Dialister;s__
#   classification_method
# 1 ANI/Placement
# 2 ANI/Placement
# 3 ANI/Placement
#   note                                                             aa_percent
# 1 topological placement and ANI have congruent species assignments 89.25
# 2 topological placement and ANI have congruent species assignments 63.73
# 3 topological placement and ANI have congruent species assignments 53.21
#   translation_table red_value warnings projectID
# 1 11                N/A       N/A      PRJEB11755
# 2 11                N/A       N/A      PRJEB11755
# 3 11                N/A       N/A      PRJEB11755

# %%
# adding checkm info
drep_res_j = drep_res_j %>%
    inner_join(gtdb, c('binID'='user_genome', 'projectID'='projectID'))

drep_res_j %>% dfhead
# Out:
# Warning message:
# “Column `binID`/`user_genome` joining character vector and factor, coercing into character vector”
# [1] 5301   56
#   binID
# 1 artificially_reared_1__metabat2_low_PE.001.contigs
# 2 artificially_reared_1__metabat2_low_PE.002.contigs
# 3 artificially_reared_1__metabat2_low_PE.008.contigs
#   fasta.x
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.008.contigs.fa
#   Marker.lineage              X..genomes X..markers X..marker.sets Completeness
# 1 o__Bacteroidales (UID2657)  160        491        268            87.24
# 2 o__Bacteroidales (UID2657)  160        491        268            92.92
# 3 o__Lactobacillales (UID543) 294        472        265            97.74
#   Contamination Strain.heterogeneity Genome.size..bp. ⋯
# 1 4.15          45.00                2455242          ⋯
# 2 3.00          28.57                3388189          ⋯
# 3 1.73          33.33                2072345          ⋯
#   closest_placement_taxonomy
# 1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__Bacteroides_A plebeius
# 2 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__Bacteroides_A sp900066445
# 3 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Lactococcus;s__Lactococcus piscium_C
#   closest_placement_ani closest_placement_af
# 1 94.69                 0.95
# 2 85.72                 0.61
# 3 98.68                 0.97
#   pplacer_taxonomy
# 1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__
# 2 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__
# 3 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Lactococcus;s__
#   classification_method
# 1 ANI
# 2 Placement
# 3 ANI/Placement
#   note                                                               aa_percent
# 1 topological placement and ANI have incongruent species assignments 80.2
# 2 taxonomic classification fully defined by topology                 93.33
# 3 topological placement and ANI have congruent species assignments   97.92
#   translation_table red_value      warnings
# 1 11                N/A            N/A
# 2 11                0.985595897806 N/A
# 3 11                N/A            N/A

# %%
# study metadata
drep_res_j = drep_res_j %>%
    inner_join(study_meta, c('projectID'='ProjectID')) 

drep_res_j %>% dfhead
# Out:
# [1] 5301   59
#   binID
# 1 artificially_reared_1__metabat2_low_PE.001.contigs
# 2 artificially_reared_1__metabat2_low_PE.002.contigs
# 3 artificially_reared_1__metabat2_low_PE.008.contigs
#   fasta.x
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.001.contigs.fa
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.002.contigs.fa
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/summary/LLMGA//MAGs/drep_99p9/dereplicated_genomes/artificially_reared_1__metabat2_low_PE.008.contigs.fa
#   Marker.lineage              X..genomes X..markers X..marker.sets Completeness
# 1 o__Bacteroidales (UID2657)  160        491        268            87.24
# 2 o__Bacteroidales (UID2657)  160        491        268            92.92
# 3 o__Lactobacillales (UID543) 294        472        265            97.74
#   Contamination Strain.heterogeneity Genome.size..bp. ⋯
# 1 4.15          45.00                2455242          ⋯
# 2 3.00          28.57                3388189          ⋯
# 3 1.73          33.33                2072345          ⋯
#   pplacer_taxonomy
# 1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__
# 2 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides_A;s__
# 3 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Lactococcus;s__
#   classification_method
# 1 ANI
# 2 Placement
# 3 ANI/Placement
#   note                                                               aa_percent
# 1 topological placement and ANI have incongruent species assignments 80.2
# 2 taxonomic classification fully defined by topology                 93.33
# 3 topological placement and ANI have congruent species assignments   97.92
#   translation_table red_value      warnings Host  Num_samples_used
# 1 11                N/A            N/A      Goose 4
# 2 11                0.985595897806 N/A      Goose 4
# 3 11                N/A            N/A      Goose 4
#   Publication_DOI
# 1 DOI: 10.1002/mbo3.429, DOI: 10.1002/mbo3.725
# 2 DOI: 10.1002/mbo3.429, DOI: 10.1002/mbo3.725
# 3 DOI: 10.1002/mbo3.429, DOI: 10.1002/mbo3.725

# %% [markdown]
# # Summary

# %% [markdown]
# ## checkM

# %%
# checkm stats
drep_res_j$Completeness %>% summary %>% print
drep_res_j$Completeness %>% sd %>% print
drep_res_j$Contamination %>% summary %>% print
drep_res_j$Contamination %>% sd %>% print

p = drep_res_j %>%
    dplyr::select(binID, Completeness, Contamination) %>%
    gather(Metric, Value, -binID) %>%
    ggplot(aes(Value)) +
    geom_histogram(bins=30) +
    labs(y='No. of MAGs') +
    facet_grid(Metric ~ ., scales='free_y') +
    theme_bw() 

dims(4,3)
plot(p)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   50.08   76.90   89.82   84.95   95.91  100.00
# [1] 13.41518
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.570   1.130   1.356   1.980   5.000
# [1] 1.084987
# plot without title

# %%
cat('Number of "high quality" genomes:', 
    drep_res_j %>% filter(Completeness >= 90) %>% nrow, '\n')
# Out:
# Number of "high quality" genomes: 2619

# %% [markdown]
# ## GTDBTk

# %%
# Total by class
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(x='Phylum;Class', y='No. of MAGs') +
    theme_bw() 

dims(7,6)
plot(p)
# Out:
# plot without title

# %%
# Total by order
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class),
           Order = gsub('^o__', '', Order)) %>%
    unite(Taxonomy, Phylum, Class, Order, sep=';', remove=FALSE) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='No. of MAGs') +
    theme_bw() 

dims(8,8)
plot(p)
# Out:
# plot without title

# %%
# Christ. genomes
drep_res_j %>%
    filter(Order == 'o__Christensenellales') %>%
    nrow %>% print
# Methanogen genomes
drep_res_j %>%
    filter(Domain == 'd__Archaea',
           grepl('^c__Methano', Class)) %>%
    nrow %>% print
# Out:
# [1] 168
# [1] 24

# %%
# no close ANI matches 
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class),
           Order = gsub('^o__', '', Order)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    mutate(closest_placement_ani = closest_placement_ani %>% as.character,
           closest_placement_ani = ifelse(closest_placement_ani == 'N/A', 
                                          0, closest_placement_ani),
           closest_placement_ani = ifelse(is.na(closest_placement_ani), 
                                          0, closest_placement_ani),
           closest_placement_ani = closest_placement_ani %>% as.Num) %>%
    mutate(has_species_placement = ifelse(closest_placement_ani >= 95,
                                          'ANI >= 95%', 'No match')) %>%
    ggplot(aes(Taxonomy, fill=Phylum)) +
    geom_bar() +
    facet_grid(. ~ has_species_placement) +
    coord_flip() +
    labs(x='Phylum;Class', y='Closest placement ANI') +
    theme_bw() 

dims(8,5)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/195ee11211d9c8576b5d20bcc083522f.RDS
# plot without title

# %%
drep_j_s = drep_res_j %>%
    filter(Genus == 'g__') %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class),
           Order = gsub('^o__', '', Order),
           Family = gsub('^f__', '', Family)) %>%
    unite(Taxonomy, Phylum, Class, Order, Family, sep=';', remove=FALSE) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup()

cat('Number of genomes lacking a genus-level classification:',
    drep_j_s$n %>% sum, '\n')

p = drep_j_s %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='No. of MAGs lacking a\ngenus-level classification') +
    theme_bw() +
    theme(
        axis.text.y = element_text(size=10),
        axis.title.y = element_blank()
    )

dims(10,9)
Plot(p)
# Out:
# Number of genomes lacking a genus-level classification: 485
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/b83075b46b92f19183c83d8909582975.RDS
# plot without title

# %%
drep_j_s = drep_res_j %>%
    filter(Family == 'f__') %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class),
           Order = gsub('^o__', '', Order)) %>%
    unite(Taxonomy, Phylum, Class, Order,  sep=';', remove=FALSE) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup()

cat('Number of genomes lacking a family-level classification:',
    drep_j_s$n %>% sum, '\n')

p = drep_j_s %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='No. of MAGs lacking a\nfamily-level classification') +
    theme_bw() +
    theme(
        axis.text.y = element_text(size=10),
        axis.title.y = element_blank()
    )

dims(8,3)
Plot(p)
# Out:
# Number of genomes lacking a family-level classification: 8
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/9f6fe373f18cd294fbc9e45f302983dd.RDS
# plot without title

# %% [markdown]
# # Summary by project

# %%
#Total by class
x = drep_res_j %>%
    group_by(Host, projectID) %>%
    summarize(n = n()) %>%
    ungroup() 

cat('Number of MAGs per study:\n')
x$n %>% summary %>% print
x$n %>% sd %>% print
# Out:
# Number of MAGs per study:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0    29.0   119.0   407.8   539.0  1525.0
# [1] 493.6592

# %%
# Total by class
p = drep_res_j %>%
    group_by(Host, projectID) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    mutate(Host = Host %>% reorder(-n),
           N = n %>% as.character) %>%
    ggplot(aes(Host, n, label=n)) +
    geom_bar(stat='identity') +
    geom_text(aes(y=n+30), size=2.5, vjust=-0.01) +
    labs(y='No. of MAGs') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(5,3)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/330d62f65eff19157a76a5043a1f4838.RDS
# plot without title

# %%
# Total by class
p = drep_res_j %>%
    group_by(Host, projectID) %>%
    summarize(n = n(),
              Num_samples_used = first(Num_samples_used)) %>%
    ungroup() %>%
    mutate(Host = Host %>% reorder(-n),
           N = n %>% as.character,
           projectID = gsub('-', '\n', projectID)) %>%
    ggplot(aes(Host, n, fill=projectID)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=n), size=2.5, vjust=-0.01) +
    geom_text(aes(y=-10, label=Num_samples_used), size=2.5, vjust=1) +
    labs(y='No. of MAGs') +
    theme_bw() +
    theme(
        legend.position = 'top',
        legend.title=element_text(size=6.5), 
        legend.text=element_text(size=6.5),
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(6,4)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/1610b0cbb54aecaa5cc5617110d5d602.RDS
# plot without title

# %%
# Total by class
p = drep_res_j %>%
    group_by(Host, projectID) %>%
    summarize(n = n(),
              Num_samples_used = first(Num_samples_used)) %>%
    ungroup() %>%
    mutate(Host = Host %>% reorder(-n),
           N = n %>% as.character,
           projectID = gsub('-', '\n', projectID)) %>%
    ggplot(aes(Host, n)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=n), size=2.7, vjust=-0.1) +
    geom_text(aes(y=-10, label=Num_samples_used), size=2.7, vjust=1.2) +
    labs(y='No. of MAGs') +
    theme_bw() +
    theme(
        legend.position = 'top',
        legend.title=element_text(size=6.5), 
        legend.text=element_text(size=6.5),
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(6,4)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/1fcddf536fdb64eae7da6b7dc4bfed6a.RDS
# plot without title

# %% [markdown]
# ## GTDBTk

# %%
# number of phyla
dt.dims(50)
cat('Number of phyla:', drep_res_j$Phylum %>% unique %>% length, '\n')
drep_res_j %>% 
    group_by(Domain, Phylum) %>%
    summarize(n = n()) 
dt.dims(4)
# Out:
# Number of phyla: 27
#    Domain      Phylum                 n
# 1  d__Archaea  p__Euryarchaeota         17
# 2  d__Archaea  p__Halobacterota          7
# 3  d__Archaea  p__Thermoplasmatota       7
# 4  d__Bacteria p__Actinobacteriota     406
# 5  d__Bacteria p__Armatimonadota         1
# 6  d__Bacteria p__Bacteroidota        1484
# 7  d__Bacteria p__Campylobacterota      20
# 8  d__Bacteria p__Chloroflexota          1
# 9  d__Bacteria p__Cyanobacteria         36
# 10 d__Bacteria p__Deferribacterota       1
# 11 d__Bacteria p__Desulfobacterota_A    29
# 12 d__Bacteria p__Elusimicrobiota        6
# 13 d__Bacteria p__Eremiobacterota        1
# 14 d__Bacteria p__Fibrobacterota         9
# 15 d__Bacteria p__Firmicutes           629
# 16 d__Bacteria p__Firmicutes_A        1762
# 17 d__Bacteria p__Firmicutes_B          21
# 18 d__Bacteria p__Firmicutes_C         215
# 19 d__Bacteria p__Fusobacteriota       209
# 20 d__Bacteria p__Myxococcota            7
# 21 d__Bacteria p__Patescibacteria        7
# 22 d__Bacteria p__Planctomycetota        4
# 23 d__Bacteria p__Proteobacteria       260
# 24 d__Bacteria p__Spirochaetota        121
# 25 d__Bacteria p__Synergistota          11
# 26 d__Bacteria p__Verrucomicrobiota     27
# 27 d__Bacteria p__Verrucomicrobiota_A    3

# %%
# Total by class
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Host, projectID, Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Taxonomy, n, fill=Host, color=Host)) +
    geom_bar(stat='identity', position='dodge') +
    #geom_point(alpha=0.5) +
    scale_y_log10() +
    coord_flip() +
    labs(y='No. of MAGs') +
    theme_bw() +
    theme(
        axis.title.y = element_blank()
    )

dims(5,6)
plot(p)
# Out:
# plot without title

# %%
# Total by class
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Host, projectID, Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    mutate(Taxonomy = Taxonomy %>% reorder(n),
           Host = stringr::str_wrap(Host, 10),
           Host = Host %>% reorder(-n)) %>%
    ggplot(aes(Taxonomy, n)) +
    geom_point(shape='|', size=3) +
    geom_bar(stat='identity') +
    #scale_y_log10(breaks=c(0,1,10,100)) +
    scale_y_continuous(breaks=c(0, 250, 500)) +
    coord_flip() +
    labs(y='No. of MAGs') +
    facet_grid(. ~ Host) +
    theme_bw() +
    theme(
        axis.title.y = element_blank(),
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(11,6)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/c6bd10dc9717ef353a41b599f2d5cc65.RDS
# plot without title

# %%
# Total by class
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Host, projectID, Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    mutate(Taxonomy = Taxonomy %>% reorder(-n),
           Host = stringr::str_wrap(Host, 10),
           Host = Host %>% reorder(-n)) %>%
    ggplot(aes(Taxonomy, n)) +
    geom_bar(stat='identity', width=0.1) +
    geom_point() +
    scale_y_continuous(breaks=c(0, 250, 500)) +
    labs(x='Phylum;Class', y='No. of MAGs') +
    facet_grid(Host ~ .) +
    theme_bw() +
    theme(
        strip.text.y = element_text(size=7),
        axis.text.x = element_text(angle=90, hjust=1, vjust=0.5)
    )

dims(6,10)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/0c9b0a9f5b7a06c5b1f34b71be148fe0.RDS
# plot without title

# %%
# Total by class
p = drep_res_j %>%
    mutate(Phylum = gsub('^p__', '', Phylum),
           Class = gsub('^c__', '', Class)) %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Host, projectID, Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    mutate(Taxonomy = Taxonomy %>% reorder(-n),
           Host = stringr::str_wrap(Host, 10),
           Host = Host %>% reorder(-n)) %>%
    ggplot(aes(Taxonomy, Host)) +
    geom_point(aes(size=n), alpha=0.2) +
    geom_point(aes(size=n), alpha=0.7, shape='O') +
    scale_size_continuous('No. of\nMAGs') +
    labs(x='Phylum;Class', y='Host') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=90, hjust=1, vjust=0.5)
    )

dims(6,5.5)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/.figures/9d1d0e1e60ceecc9478c1b49865b0f27.RDS
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
# [1] en_US.UTF-8
#
# attached base packages:
# [1] parallel  stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] bindrcpp_0.2.2          future.apply_1.0.0      future.batchtools_0.7.1
#  [4] future_1.9.0            doParallel_1.0.11       iterators_1.0.10
#  [7] foreach_1.4.4           data.table_1.11.4       ggplot2_3.0.0
# [10] readxl_1.1.0            tidyr_0.8.1             dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-2      progress_1.2.0    tidyselect_0.2.4  repr_0.15.0
#  [5] reshape2_1.4.3    purrr_0.2.4       listenv_0.7.0     colorspace_1.3-2
#  [9] htmltools_0.3.6   base64enc_0.1-3   rlang_0.2.1       pillar_1.2.2
# [13] glue_1.3.0        withr_2.1.1       rappdirs_0.3.1    uuid_0.1-2
# [17] bindr_0.1.1       plyr_1.8.4        stringr_1.3.1     munsell_0.5.0
# [21] gtable_0.2.0      cellranger_1.1.0  codetools_0.2-15  evaluate_0.10.1
# [25] labeling_0.3      batchtools_0.9.11 IRdisplay_0.4.4   Rcpp_0.12.17
# [29] scales_0.5.0      backports_1.1.2   checkmate_1.8.5   IRkernel_0.8.12
# [33] jsonlite_1.5      brew_1.0-6        hms_0.4.2         digest_0.6.15
# [37] stringi_1.2.3     grid_3.4.1        tools_3.4.1       magrittr_1.5
# [41] base64url_1.4     lazyeval_0.2.1    tibble_1.4.2      crayon_1.3.4
# [45] pkgconfig_2.0.1   prettyunits_1.0.2 assertthat_0.2.0  R6_2.2.2
# [49] globals_0.12.2    compiler_3.4.1
