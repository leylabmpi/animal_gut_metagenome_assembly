# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Metadata" data-toc-modified-id="Metadata-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Metadata</a></span></li><li><span><a href="#Number-of-raw-assembled-sequences" data-toc-modified-id="Number-of-raw-assembled-sequences-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Number of raw assembled sequences</a></span><ul class="toc-item"><li><span><a href="#Animal-gut" data-toc-modified-id="Animal-gut-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Animal gut</a></span></li><li><span><a href="#multi-study" data-toc-modified-id="multi-study-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>multi-study</a></span></li></ul></li><li><span><a href="#Merging-cluster-reps" data-toc-modified-id="Merging-cluster-reps-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Merging cluster reps</a></span><ul class="toc-item"><li><span><a href="#Georg-animal-gut" data-toc-modified-id="Georg-animal-gut-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Georg animal gut</a></span></li><li><span><a href="#Multi-study" data-toc-modified-id="Multi-study-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Multi-study</a></span></li></ul></li><li><span><a href="#Summarizing-number-of-reps-per-study" data-toc-modified-id="Summarizing-number-of-reps-per-study-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Summarizing number of reps per study</a></span><ul class="toc-item"><li><span><a href="#Counting-seqs" data-toc-modified-id="Counting-seqs-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Counting seqs</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#Clustering-reps" data-toc-modified-id="Clustering-reps-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Clustering reps</a></span><ul class="toc-item"><li><span><a href="#LLMGAG" data-toc-modified-id="LLMGAG-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>LLMGAG</a></span><ul class="toc-item"><li><span><a href="#Run" data-toc-modified-id="Run-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Run</a></span></li></ul></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Number-of-gene-clusters" data-toc-modified-id="Number-of-gene-clusters-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Number of gene clusters</a></span></li><li><span><a href="#Taxonomy" data-toc-modified-id="Taxonomy-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Taxonomy</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#COG" data-toc-modified-id="COG-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>COG</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Adding-taxonomy" data-toc-modified-id="Adding-taxonomy-9.3.0.1"><span class="toc-item-num">9.3.0.1&nbsp;&nbsp;</span>Adding taxonomy</a></span></li></ul></li><li><span><a href="#Sum-by-COG-functional-categories" data-toc-modified-id="Sum-by-COG-functional-categories-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>Sum by COG functional categories</a></span><ul class="toc-item"><li><span><a href="#Grouped-by-taxonomy" data-toc-modified-id="Grouped-by-taxonomy-9.3.1.1"><span class="toc-item-num">9.3.1.1&nbsp;&nbsp;</span>Grouped by taxonomy</a></span></li></ul></li></ul></li><li><span><a href="#KEGG-pathway" data-toc-modified-id="KEGG-pathway-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>KEGG pathway</a></span></li><li><span><a href="#CAZy" data-toc-modified-id="CAZy-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>CAZy</a></span></li><li><span><a href="#Humann2-db-genes" data-toc-modified-id="Humann2-db-genes-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Humann2 db genes</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-9.6.1"><span class="toc-item-num">9.6.1&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#By-taxonomy" data-toc-modified-id="By-taxonomy-9.6.1.1"><span class="toc-item-num">9.6.1.1&nbsp;&nbsp;</span>By taxonomy</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Merge all per-study 90% seqID cluster reps from all LLMGAG runs
#   * multi-study + georg animal gut
# * Cluster reps at 90% seqID
# * Summarize the merged dataset

# %% [markdown]
# # Var

# %%
work_dir = file.path('/ebio/abt3_projects/Georg_animal_feces/data/metagenome',
                     'multi-study', 'BioProjects', 'merged', 'linclust90')

# georg animal gut metagenomes
GA_base_out_dir = '/ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/wOutVertebrata/'
GA_out_dirs = c('MG_assembly_act', 'MG_assembly_amp', 'MG_assembly_rep', 'MG_assembly_ave', 'MG_assembly_mam')

# multi-study metagenomes
MS_base_out_dir = '/ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/'
MS_out_dirs = c('PRJEB11755', 'PRJEB20308', 'PRJEB29346',
                'PRJNA336354', 'PRJNA381379', 'PRJNA417359',
                'PRJNA532626', 'PRJNA476660', 'PRJNA485217',
                'PRJNA316560-PRJNA316570', 'PRJEB22765',
                'PRJEB23642', 'PRJEB9357')
MS_meta_file = '/ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/metadata/study_metadata_v2.xlsx'


# params
pipeline_dir = '/ebio/abt3_projects/methanogen_host_evo/bin/llmgag/'
conda_env = 'mmseqs'
threads = 24

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(dtplyr)
library(tidytable)
library(doParallel)
library(LeyLabRMisc)

# %%
make_dir(work_dir)
setDTthreads(threads)
df.dims()
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90

# %% [markdown]
# # Metadata

# %%
MS_meta = readxl::read_excel(MS_meta_file) %>%
    dplyr::select(-Publication_DOI) %>%
    rename('No_samples' = Num_samples_used)
df = data.frame('ProjectID' = c('Georg_animal'),
                'Host' = c('Five classes'),
                'No_samples' = c(290))
MS_meta = rbind(MS_meta, df) %>%
    as.data.table
MS_meta
# Out:
#    ProjectID    Host             No_samples
# 1  PRJEB11755   Pig              100
# 2  PRJEB20308   Dog              100
# ⋮  ⋮            ⋮                ⋮
# 13 PRJNA532626  Black rhinoceros  25
# 14 Georg_animal Five classes     290

# %% [markdown]
# # Number of raw assembled sequences

# %% [markdown]
# ## Animal gut

# %%
#'' counting raw sequences in a file
count_seqs = function(D, base_dir, compressed=FALSE){
    F = file.path(base_dir, D, 'LLMGAG', 'assembly', 'plass', 'genes.faa')
    cmd = ''
    if(compressed == TRUE){
        cmd = glue::glue('pigz -d -c {file}.gz | grep -c \'>\'', file=F)         
    } else {
        cmd = glue::glue('grep -c \'>\' {file}', file=F) 
    }
    bash_job(cmd, conda_env='py3_genome', stdout=TRUE, print_output=FALSE)
}

# %%
registerDoParallel(threads)
multiSpec_nseqs = plyr::llply(as.list(GA_out_dirs), count_seqs, base_dir=GA_base_out_dir, .parallel=TRUE) 
multiSpec_nseqs
# Out:
# [[1]]
# [1] "13293278"
#
# [[2]]
# [1] "3355557"
#
# [[3]]
# [1] "10866795"
#
# [[4]]
# [1] "53270560"
#
# [[5]]
# [1] "201061420"

# %%
cat('mult-species: total number of assembled sequences:', 
    multiSpec_nseqs %>% as.Num %>% sum, '\n')
# Out:
# mult-species: total number of assembled sequences: 281847610

# %% [markdown]
# ## multi-study

# %%
# counting raw sequences
registerDoParallel(threads)
multiStudy_nseqs = plyr::llply(as.list(MS_out_dirs), count_seqs, 
                               base_dir=MS_base_out_dir, compressed=TRUE,
                               .parallel=TRUE) 
multiStudy_nseqs
# Out:
# [[1]]
# [1] "1084240"
#
# [[2]]
# [1] "358941475"
#
# [[3]]
# [1] "14607288"
#
# [[4]]
# [1] "11161249"
#
# [[5]]
# [1] "9005167"
#
# [[6]]
# [1] "464917761"
#
# [[7]]
# [1] "218041996"
#
# [[8]]
# [1] "28740865"
#
# [[9]]
# [1] "22883942"
#
# [[10]]
# [1] "298937"
#
# [[11]]
# [1] "184470"
#
# [[12]]
# [1] "119545122"
#
# [[13]]
# [1] "181804409"

# %%
cat('mult-study: total number of assembled sequences: ', 
    multiStudy_nseqs %>% as.Num %>% sum, '\n')
# Out:
# mult-study: total number of assembled sequences:  1431216921

# %%
cat('multi-species + multi-study: total number of assembled sequences: ', 
    multiSpec_nseqs %>% as.Num %>% sum + multiStudy_nseqs %>% as.Num %>% sum, '\n')
# Out:
# multi-species + multi-study: total number of assembled sequences:  1713064531

# %% [markdown]
# # Merging cluster reps

# %%
# checking for already existing merged seqs
out_file = file.path(work_dir, 'clusters_rep-seqs.faa')
if(file.exists(out_file)){
    #file.remove(out_file)
}

# %% [markdown]
# ## Georg animal gut

# %%
# merging (cat) sequences
merge_seqs = function(D, base_dir, out_file){
    F = file.path(base_dir, D, 'LLMGAG', 'cluster', 'linclust', 'clusters_rep-seqs.faa')
    cmd = glue::glue('cat {file} >> {out_file}', file=F, out_file=out_file) 
    bash_job(cmd, conda_env='py3')
}

## WARNING: uncomment to re-merge
#plyr::llply(as.list(GA_out_dirs), merge_seqs, base_dir=GA_base_out_dir, out_file=out_file)

# %%
# number of merged rep sequences
cmd = glue::glue('grep -c ">" {fasta}', fasta=out_file)
n_seqs = as.numeric(system(cmd, intern=TRUE))
cat('Number of rep sequences:', n_seqs , '\n\n')

# %% [markdown]
# ## Multi-study

# %%
## WARNING: uncomment to re-merge
#plyr::llply(as.list(MS_out_dirs), merge_seqs, base_dir=MS_base_out_dir, out_file=out_file)

# %%
# number of merged rep sequences
cmd = glue::glue('grep -c ">" {fasta}', fasta=out_file)
n_seqs = as.numeric(system(cmd, intern=TRUE))
cat('Number of rep sequences:', n_seqs , '\n\n')

# %% [markdown]
# # Summarizing number of reps per study

# %% [markdown]
# ## Counting seqs

# %%
# multi-study
count_seqs = function(D, base_dir){
    F = file.path(base_dir, D, 'LLMGAG', 'cluster', 'linclust', 'clusters_rep-seqs.faa')
    cmd = glue::glue('grep -c \'>\' {file}', file=F) 
    cnt = bash_job(cmd, conda_env='py3', stdout=TRUE, print_output=FALSE)
    return(as.numeric(cnt))
}

registerDoParallel(threads)
cnts = plyr::llply(as.list(MS_out_dirs), count_seqs, base_dir=MS_base_out_dir,
                   .parallel=TRUE) %>%
    unlist()

cnts = data.frame(studyID = MS_out_dirs,
                  n_seqs = cnts)
cnts
# Out:
#    studyID    n_seqs
# 1  PRJEB11755    877842
# 2  PRJEB20308 128248670
# ⋮  ⋮          ⋮
# 12 PRJEB23642 150815
# 13 PRJEB9357  150815

# %%
# multi-species
cnts = data.frame(studyID = c('Georg_animal'),
                 n_seqs = c(29035083)) %>%
    rbind(cnts)

cnts
# Out:
#    studyID      n_seqs
# 1  Georg_animal 29035083
# 2  PRJEB11755     877842
# ⋮  ⋮            ⋮
# 13 PRJEB23642   150815
# 14 PRJEB9357    150815

# %%
# adding study metadata
cnts = cnts %>%
    left_join(MS_meta, c('studyID'='ProjectID')) 

cnts
# Out:
# Warning message:
# “Column `studyID`/`ProjectID` joining factor and character vector, coercing into character vector”
#    studyID      n_seqs   Host         No_samples
# 1  Georg_animal 29035083 Five classes 290
# 2  PRJEB11755     877842 Pig          100
# ⋮  ⋮            ⋮        ⋮            ⋮
# 13 PRJEB23642   150815   Minke whale  12
# 14 PRJEB9357    150815   House cat    84

# %% [markdown]
# ## Summary
#
# Note: this is BEFORE a final clustering of all together

# %%
p = cnts %>%
    mutate(Host = Host %>% reorder(-n_seqs),
           n_seqs_txt = round(n_seqs / 1e6,2) %>% as.character) %>%
    ggplot(aes(Host, n_seqs, label=n_seqs_txt)) +
    geom_bar(stat='identity') +
    geom_text(vjust=-0.2, size=2) +
    scale_y_log10() +
    labs(y='No. of 90% rep. seqs.') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(5,3.5)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/notebooks/metagenome/multi-study/09_LLMGAG_all_cluster/01_linclust90/.figures/288767fab42c431b77d545d9f0fba766.RDS
# plot without title

# %% [markdown]
# # Clustering reps

# %% [markdown]
# ## LLMGAG
#
# * starting with merged reps at linclust step in the pipeline
#   * moved merged rep seqs to `$WORKDIR/assembly/plass/genes.faa`
#   * skipped raw & assembly steps of the pipeline

# %%
# config file
cat_file(file.path(work_dir, 'config.yaml'))
# Out:
# #-- I/O --#
# # table with sample --> read_file information
# samples_file: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90/samples_filler.txt
#
# # output location
# output_dir: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90/
#
# # cluster reps
# ## If a fasta file (AA seqs) provided, the pipeline will start at the linclust step
# aa_fasta: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90/clusters_rep-seqs.faa
#
# #-- database --#
# ## eggnog mapper
# eggnog_diamond_db: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog_proteins.dmnd
# eggnog_db: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog.db
# ## mmseqs taxonomy
# mmseqs_tax_db: /ebio/abt3_projects/databases_no-backup/uniclust/uniclust50/uniclust50_2018_08_consensus
# ## checkM
# checkM_data: /ebio/abt3_projects/databases_no-backup/checkM/
# ## sourmash
# sourmash_db: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.sbt.json
# sourmash_lca_db: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.lca.json.gz
# # humann2 diamond
# humann2_diamond_db: /ebio/abt3_projects/databases_no-backup/humann2/uniref50/uniref50_annotated.1.1.dmnd
# # empanada
# empanada_kegg_db: /ebio/abt3_projects/databases_no-backup/empanada/KOvsPATHWAY_BACTERIAL_KEGG_2013_07_15.tab
# empanada_ptwy_db: /ebio/abt3_projects/databases_no-backup/empanada/map_kegg-pwy_name.txt.gz
#
# #-- main params --#
# ## co-assemble all samples together or each sample individually?
# all_sample_coassembly: False
#
# #-- software parameters --#
# # Notes:
# ## Use "Skip" to skip any step. If no params, just use ""
# ## Note: You must skip either metacompass_megahit or metacompass_metaspades (or both)
# params:
#   # reads
#   subsample_reads: Skip     # (eg., 1000000)
#   fastqc_on_raw: ""
#   # assembly
#   plass: --num-iterations 12 --min-seq-id 0.9
#   # gene clustering
#   linclust: --min-seq-id 0.90 -c 0.9 --kmer-per-seq 50
#   # annotation
#   eggnog_mapper_jobs: 300    # number of parallel batched jobs
#   eggnog_mapper: ""
#   eggnog_mapper_annot: ""
#   # pathways
#   empanada: --abundance_threshold 0.0
#   # taxonomy
#   mmseqs_tax_jobs: 300       # number of parallel batched jobs
#   mmseqs_tax: -e 1e-5 --max-seqs 200 --lca-ranks "superkingdom:kingdom:phylum:class:order:family:genus:species"
#   # mapping
#   mmseqs_map: Skip #-s 2 -c 0.9 --cov-mode 2
#   mmseqs_blast_filter: --qcov 0.95 --seq-id 0.95 --e-value 1e-20
#   mmseqs_blast_to_bam: --mapq 30
#   merge_tables: --no-dask    # dask is currently broken
#   # formatting for humann2 db
#   diamond: --evalue 1e-5 --sensitive
#   diamond_db_to_mem: True
#
# #-- snakemake pipeline --#
# pipeline:
#   snakemake_folder: ./
#   script_folder: bin/scripts/
#   temp_folder: /tmp/global2/    # <-- your username will automatically be added

# %% [markdown]
# ### Run

# %% [markdown]
# ```
# (base) @ rick:/ebio/abt3_projects/methanogen_host_evo/bin/llmgag
# screen -L -S llmgag-all ./snakemake_sge.sh /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90/config.yaml cluster.json /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/merged/linclust90/SGE_log 50
# ```

# %%
pipelineInfo(pipeline_dir)
# Out:
# LLMGAG
# ======
#
# Ley Lab Metagenome Assembly of Genes (LLMGAG)
#
# * Version: 0.1.4
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/annotate.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - pigz
# - bioconda::fasta-splitter
# - bioconda::eggnog-mapper
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/checkm.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - python=2
# - pigz
# - bioconda::prodigal
# - bioconda::pplacer
# - bioconda::checkm-genome
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/das_tool.yaml <==
# channels: !!python/tuple
# - r
# - bioconda
# dependencies:
# - pigz
# - ruby
# - r::r-base
# - r::r-data.table
# - r::r-domc
# - r::r-ggplot2
# - bioconda::pullseq
# - bioconda::prodigal
# - bioconda::blast
# - bioconda::diamond
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/dask.yaml <==
# channels: !!python/tuple
# - conda-forge
# dependencies:
# - conda-forge::dask=0.18.1
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/empanda.yaml <==
# channels: !!python/tuple
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - conda-forge::numpy=1.15
# - conda-forge::pandas
# - conda-forge::r-argparse
# - conda-forge::r-dplyr
# - conda-forge::r-tidyr
# - conda-forge::r-stringr
# - conda-forge::r-data.table
# - pip:
#   - empanada
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/hadley.yaml <==
# channels: !!python/tuple
# - conda-forge
# dependencies:
# - conda-forge::r-ape
# - conda-forge::r-dplyr
# - conda-forge::r-tidyr
# - conda-forge::r-ggplot2
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/humann2.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - pigz
# - bioconda::prodigal
# - bioconda::diamond=0.8.36
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/metabat2.yaml <==
# channels: !!python/tuple
# - BioBuilds
# - bioconda
# dependencies:
# - pigz
# - python=2.7
# - BioBuilds::boost>=1.55.0
# - scons>=2.1.0
# - zlib>=1.2.4
# - BioBuilds::binutils>=2.2.2
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/multiqc.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - bioconda::fastqc
# - bioconda::multiqc
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/plass.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - pigz
# - bioconda::seqtk
# - bioconda::samtools
# - bioconda::mmseqs2
# - bioconda::plass
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/sourmash.yaml <==
# channels: !!python/tuple
# - bioconda
# dependencies:
# - bioconda::sourmash=2.0.0a9
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmgag//bin/envs/vamb.yaml <==
# channels: !!python/tuple
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - pytorch
# - numpy
# - pysam

# %% [markdown]
# # Summary

# %% [markdown]
# ## Number of gene clusters

# %%
F = file.path(work_dir, 'cluster', 'linclust', 'clusters_rep-seqs.faa')
cmd = glue::glue('grep -c ">" {fasta}', fasta=F)
n_rep_seqs = system(cmd, intern=TRUE)
cat('Number of cluster rep sequences:', n_rep_seqs, '\n')
# Out:
# Number of cluster rep sequences: 140225322

# %%
F = file.path(work_dir, 'humann2_db', 'clusters_rep-seqs.faa.gz')
cmd = glue::glue('gunzip -c {fasta} | grep -c ">"', fasta=F)
n_h2_seqs = system(cmd, intern=TRUE)
cat('Number of humann2_db-formatted seqs:', n_h2_seqs, '\n')
# Out:
# Number of humann2_db-formatted seqs: 23823220

# %% [markdown]
# ## Taxonomy

# %%
# reading in taxonomy table
## WARING: slow
F = file.path(work_dir, 'taxonomy', 'clusters_rep-seqs_tax_db.tsv.gz')
#cmd = glue::glue('gunzip -c {file} | head -n 10000', file=F) 
cmd = glue::glue('gunzip -c {file}', file=F) 
coln = c('seqID', 'taxID', 'rank', 'spp', 'lineage')
levs = c('Domain', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species', 'X')
tax = fread(cmd=cmd, sep='\t', header=FALSE, col.names=coln, fill=TRUE) %>%
    dt_separate(lineage, levs, sep=':') %>%
    dt_select(-X, -taxID, -rank, -spp) %>%
    dt_filter(Domain %in% c('Archaea', 'Bacteria', 'Viruses'),
              !(Domain %in% c('Archaea','Bacteria', '') & 
                Phylum %in% c('unknown', 'uc_Bacteria', ''))
             ) %>%
    dt_rename('seqid' = seqID)
              
tax
# Out:
#           seqid                            Domain   Kingdom Phylum
# 1         2a2cefdec88e4aa8abfc87c17023aac1 Bacteria unknown Proteobacteria
# 2         9a4e8354a7744f6abec5d85e0ac2a428 Bacteria unknown Proteobacteria
# ⋮         ⋮                                ⋮        ⋮       ⋮
# 104229207 f0b139c18f7946d396e00670a720f76f Bacteria unknown Firmicutes
# 104229208 8b2bb0e4f6674c5486fd616ef2659691 Bacteria unknown Firmicutes
#           Class              Order            Family            Genus
# 1         Betaproteobacteria Nitrosomonadales unknown           unknown
# 2         Betaproteobacteria Nitrosomonadales Nitrosomonadaceae Nitrosomonas
# ⋮         ⋮                  ⋮                ⋮                 ⋮
# 104229207 Clostridia         Clostridiales    Lachnospiraceae   unknown
# 104229208 Clostridia         Clostridiales    Clostridiaceae    Anaeromicrobium
#           Species
# 1         Gallionellales bacterium RIFOXYB12_FULL_54_9
# 2         Nitrosomonas sp. Nm33
# ⋮         ⋮
# 104229207 [Eubacterium] rectale
# 104229208 Anaeromicrobium sediminis

# %%
# number of sequences
tax %>%
    dt_distinct(seqid) %>% 
    dt_pull(seqid) %>% length %>% 
    cat('No. of arch/bac/virus sequences', ., '\n')
# Out:
# No. of arch/bac/virus sequences 104229208

# %% [markdown]
# ### Summary

# %%
# summarizing taxonomy
tax_s = tax %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(Domain, Phylum)) %>%
    dt_arrange(-n)

df.dims(20)
tax_s %>% dt_slice_head(20)
df.dims()
# Out:
#    Domain   Phylum          n
# 1  Bacteria Bacteroidetes   51619739
# 2  Bacteria Firmicutes      30208653
# 3  Bacteria Proteobacteria  11678133
# 4  Bacteria Fusobacteria     4007680
# 5  Bacteria Actinobacteria   2494762
# 6  Viruses  unknown           522641
# 7  Bacteria Spirochaetes      492706
# 8  Bacteria Chlamydiae        289837
# 9  Bacteria Tenericutes       269334
# 10 Bacteria Verrucomicrobia   255684
# 11 Archaea  Euryarchaeota     227740
# 12 Bacteria Chloroflexi       218284
# 13 Bacteria Cyanobacteria     210904
# 14 Bacteria Acidobacteria     173220
# 15 Bacteria Fibrobacteres     147628
# 16 Bacteria Planctomycetes    140233
# 17 Bacteria Synergistetes     109585
# 18 Bacteria Deferribacteres   107362
# 19 Bacteria Thermotogae        89282
# 20 Bacteria Ignavibacteriae    84120

# %%
# plotting by phylum (w/ count cutoff)
p = tax_s %>%
    dt_filter(n >= 10000) %>%
    dt_mutate(Phylum = reorder(Phylum, n)) %>%
    ggplot(aes(Phylum, n, fill=Domain)) +
    geom_bar(stat='identity', position='dodge') +
    geom_text(aes(y=sqrt(n), label=n), size=3, color='white') +
    scale_y_log10() +
    labs(y = 'No. of clusters') +
    coord_flip() +
    theme_bw() +
    theme(
        axis.text.y = element_text(size=9),
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(4,5.5)
plot(p)
# Out:
# plot without title

# %%
# top phyla
df.dims(20)
tax_s %>% 
    dt_arrange(-n) %>%
    dt_slice_head(n=20)
df.dims()
# Out:
#    Domain   Phylum          n
# 1  Bacteria Bacteroidetes   51619739
# 2  Bacteria Firmicutes      30208653
# 3  Bacteria Proteobacteria  11678133
# 4  Bacteria Fusobacteria     4007680
# 5  Bacteria Actinobacteria   2494762
# 6  Viruses  unknown           522641
# 7  Bacteria Spirochaetes      492706
# 8  Bacteria Chlamydiae        289837
# 9  Bacteria Tenericutes       269334
# 10 Bacteria Verrucomicrobia   255684
# 11 Archaea  Euryarchaeota     227740
# 12 Bacteria Chloroflexi       218284
# 13 Bacteria Cyanobacteria     210904
# 14 Bacteria Acidobacteria     173220
# 15 Bacteria Fibrobacteres     147628
# 16 Bacteria Planctomycetes    140233
# 17 Bacteria Synergistetes     109585
# 18 Bacteria Deferribacteres   107362
# 19 Bacteria Thermotogae        89282
# 20 Bacteria Ignavibacteriae    84120

# %%
# summarizing taxonomy (by class)
tax_s = tax %>%
    dt_filter(Class != '') %>%
    dt_summarize(n = n_distinct(seqid), 
              by=list(Domain, Phylum, Class)) 
 
tax_s
# Out:
#     Domain   Phylum                   Class                       n
# 1   Bacteria Proteobacteria           Betaproteobacteria          2438610
# 2   Bacteria Proteobacteria           Gammaproteobacteria         7501202
# ⋮   ⋮        ⋮                        ⋮                           ⋮
# 303 Bacteria Candidatus Woesebacteria uc_Candidatus Woesebacteria 1
# 304 Bacteria Candidatus Omnitrophica  uc_Candidatus Omnitrophica  1

# %%
# top hits
df.dims(20)
tax_s %>%
    dt_arrange(-n) %>%
    dt_slice_head(n=20)
df.dims()
# Out:
#    Domain   Phylum         Class                 n
# 1  Bacteria Bacteroidetes  Bacteroidia           45885351
# 2  Bacteria Firmicutes     Clostridia            20034318
# 3  Bacteria Proteobacteria Gammaproteobacteria    7501202
# 4  Bacteria Firmicutes     Bacilli                4409864
# 5  Bacteria Fusobacteria   Fusobacteriia          4007680
# 6  Bacteria Proteobacteria Betaproteobacteria     2438610
# 7  Bacteria Bacteroidetes  unknown                2095956
# 8  Bacteria Firmicutes     Erysipelotrichia       2048859
# 9  Bacteria Firmicutes     unknown                1730966
# 10 Bacteria Firmicutes     Negativicutes          1606775
# 11 Bacteria Bacteroidetes  Flavobacteriia         1606449
# 12 Bacteria Actinobacteria Actinobacteria         1591841
# 13 Bacteria Bacteroidetes  Cytophagia              980497
# 14 Bacteria Actinobacteria Coriobacteriia          837671
# 15 Bacteria Proteobacteria Alphaproteobacteria     583897
# 16 Bacteria Proteobacteria Deltaproteobacteria     555602
# 17 Bacteria Bacteroidetes  Sphingobacteriia        533777
# 18 Viruses  unknown        unknown                 522641
# 19 Bacteria Spirochaetes   Spirochaetia            404790
# 20 Bacteria Proteobacteria Epsilonproteobacteria   294551

# %%
# number of phyla
df.dims(20)
tax_s %>%
    dt_filter(n >= 100) %>%
    dt_distinct(Phylum, Domain) %>%
    dt_count(Domain)
df.dims()
# Out:
#   Domain   N
# 1 Bacteria 131
# 2 Viruses    1
# 3 Archaea   15

# %%
# number of Candidatus phyla
df.dims(20)
tax_s %>%
    dt_filter(n >= 100,
              grepl('Candid', Phylum)) %>%
    dt_distinct(Phylum, Domain) %>%
    dt_count(Domain)
df.dims()
# Out:
#   Domain   N
# 1 Bacteria 86
# 2 Archaea  10

# %%
# clearing memory
rm(tax_s)
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used   (Mb)
# Ncells  105159341  5616.2  346098786 18483.7  281400522 15028.5
# Vcells 2530296507 19304.7 8107841978 61858.0 8091421704 61732.7

# %% [markdown]
# ## COG

# %%
# eggnog-mapper v2
cols = c(
"query_name",
"seed_eggNOG_ortholog",
"seed_ortholog_evalue",
"seed_ortholog_score",
"Predicted_taxonomic_group",
"Predicted_protein_name",
"Gene_Ontology_terms",
"EC_number",
"KEGG_ko",
"KEGG_Pathway",
"KEGG_Module",
"KEGG_Reaction",
"KEGG_rclass",
"BRITE",
"KEGG_TC",
"CAZy",
"BiGG_Reaction",
"tax_scope__eggNOG_taxonomic_level_used_for_annotation",
"eggNOG_OGs",
"bestOG",
"COG_Functional_Category",
"eggNOG_free_text_description"
)

# %%
F = file.path(work_dir, 'annotate', 'eggnog-mapper', 'clusters_rep-seqs.emapper.annotations.gz')
cmd = glue::glue('gunzip -c {file}', file=F, header=FALSE) 
#cmd = glue::glue('gunzip -c {file} | head -n 10000', file=F, header=FALSE) 
COG_annot = fread(cmd=cmd, sep='\t') 
colnames(COG_annot) = cols
## separate
max_feats = COG_annot %>%
    dt_mutate(n_feats = stringr::str_length(COG_Functional_Category)) %>%
    dt_pull(n_feats) %>% max
cat('Max No. of features:', max_feats, '\n')
new_cols = gsub('^', 'X', 1:(max_feats))
COG_annot = COG_annot %>%
    dt_select(query_name, COG_Functional_Category) %>%
    dt_separate(COG_Functional_Category, into=new_cols, sep='') %>%
    dt_pivot_longer(cols=c(-query_name), names_to='X', values_to='COG_cat') %>%
    dt_filter(!is.na(COG_cat)) %>%
    dt_select(-X) %>%
    dt_rename(seqid = query_name)
COG_annot
# Out:
# Max No. of features: 6
#           seqid                            COG_cat
# 1         3ba65a723e284ae79a91391e60dc08b9 J
# 2         213235bc5ad542b1877ca66722f872de S
# ⋮         ⋮                                ⋮
# 110107711 9b90a0bc020446c28dfd744467bdf707 Z
# 110107712 013ed7793b524e9da3ea3bbdc557f392 Z

# %%
# Loading function group descriptions
COG_func_cat_file = '/ebio/abt3_projects/databases_no-backup/humann2/utility_mapping/COG_cateogories.tsv'
COG_func_cat = fread(COG_func_cat_file, sep='\t') %>%
    dt_rename(COG_cat = COG_category)
COG_func_cat
# Out:
#    COG_cat Functional_description
# 1  D       Cell cycle control, cell division, chromosome partitioning
# 2  M       Cell wall/membrane/envelope biogenesis
# ⋮  ⋮       ⋮
# 24 R       General function prediction only
# 25 S       Function unknown
#    Functional_group
# 1  Cellular processes and signaling
# 2  Cellular processes and signaling
# ⋮  ⋮
# 24 Poorly characterized
# 25 Poorly characterized

# %%
# checking key overlap
overlap(COG_annot %>% dt_distinct(COG_cat) %>% dt_pull(COG_cat),
        COG_func_cat %>% dt_distinct(COG_cat) %>% dt_pull(COG_cat))
# Out:
# intersect(x,y): 24
# setdiff(x,y): 0
# setdiff(y,x): 1
# union(x,y): 25

# %%
# joining
COG_annot = COG_annot %>%
    dt_left_join(COG_func_cat, c('COG_cat'))
COG_annot
# Out:
#           seqid                            COG_cat
# 1         3ba65a723e284ae79a91391e60dc08b9 J
# 2         213235bc5ad542b1877ca66722f872de S
# ⋮         ⋮                                ⋮
# 110107711 9b90a0bc020446c28dfd744467bdf707 Z
# 110107712 013ed7793b524e9da3ea3bbdc557f392 Z
#           Functional_description
# 1         Translation, ribosomal structure and biogenesis
# 2         Function unknown
# ⋮         ⋮
# 110107711 Cytoskeleton
# 110107712 Cytoskeleton
#           Functional_group
# 1         Information storage and processing
# 2         Poorly characterized
# ⋮         ⋮
# 110107711 Cellular processes and signaling
# 110107712 Cellular processes and signaling

# %% [markdown]
# #### Adding taxonomy

# %%
# checking key overlap
overlap(COG_annot %>% dt_distinct(seqid) %>% dt_pull(seqid),
        tax %>% dt_distinct(seqid) %>% dt_pull(seqid))
# Out:
# intersect(x,y): 94046749
# setdiff(x,y): 10194186
# setdiff(y,x): 10182459
# union(x,y): 114423394

# %%
# adding taxonomy info
COG_annot = COG_annot %>%
    dt_inner_join(tax, by=c('seqid')) 

COG_annot
# Out:
#          seqid                            COG_cat
# 1        2a2cefdec88e4aa8abfc87c17023aac1 G
# 2        2a2cefdec88e4aa8abfc87c17023aac1 M
# ⋮        ⋮                                ⋮
# 99249393 f0b139c18f7946d396e00670a720f76f L
# 99249394 8b2bb0e4f6674c5486fd616ef2659691 P
#          Functional_description
# 1        Carbohydrate transport and metabolism
# 2        Cell wall/membrane/envelope biogenesis
# ⋮        ⋮
# 99249393 Replication, recombination and repair
# 99249394 Inorganic ion transport and metabolism
#          Functional_group                   Domain   Kingdom Phylum
# 1        Metabolism                         Bacteria unknown Proteobacteria
# 2        Cellular processes and signaling   Bacteria unknown Proteobacteria
# ⋮        ⋮                                  ⋮        ⋮       ⋮
# 99249393 Information storage and processing Bacteria unknown Firmicutes
# 99249394 Metabolism                         Bacteria unknown Firmicutes
#          Class              Order            Family          Genus
# 1        Betaproteobacteria Nitrosomonadales unknown         unknown
# 2        Betaproteobacteria Nitrosomonadales unknown         unknown
# ⋮        ⋮                  ⋮                ⋮               ⋮
# 99249393 Clostridia         Clostridiales    Lachnospiraceae unknown
# 99249394 Clostridia         Clostridiales    Clostridiaceae  Anaeromicrobium
#          Species
# 1        Gallionellales bacterium RIFOXYB12_FULL_54_9
# 2        Gallionellales bacterium RIFOXYB12_FULL_54_9
# ⋮        ⋮
# 99249393 [Eubacterium] rectale
# 99249394 Anaeromicrobium sediminis

# %%
COG_annot %>% dt_distinct(seqid) %>% dt_pull(seqid) %>% length %>%
    cat('Number of rep seqs with COG annotations:', ., '\n')
# Out:
# Number of rep seqs with COG annotations: 94046749

# %% [markdown]
# ### Sum by COG functional categories
#
# * [wiki on categories](https://ecoliwiki.org/colipedia/index.php/Clusters_of_Orthologous_Groups_%28COGs%29)

# %%
# summarizing
total_clusts = COG_annot %>% dt_distinct(seqid) %>% dt_pull(seqid) %>% length

COG_annot_s = COG_annot %>%
    dt_distinct(seqid, COG_cat, Functional_group) %>%
    dt_summarize(N = n_distinct(seqid), 
                 by=list(COG_cat, Functional_group)) %>%
    dt_mutate(perc_abund = N / total_clusts * 100)

COG_annot_s
# Out:
#    COG_cat Functional_group                 N       perc_abund
# 1  G       Metabolism                       9377838 9.971464
# 2  M       Cellular processes and signaling 8206688 8.726179
# ⋮  ⋮       ⋮                                ⋮       ⋮
# 23 W       Cellular processes and signaling 25027   2.661123e-02
# 24 Y       Cellular processes and signaling     2   2.126602e-06

# %%
# plotting summary
p = COG_annot_s %>%
    dt_mutate(Functional_group = stringr::str_wrap(Functional_group, 10)) %>%
    ggplot(aes(COG_cat, N, fill=Functional_group)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=formatC(N, format='e', digits=0)), hjust=-0.1, size=3) +
    scale_y_continuous(limits=c(0, 1.8e7)) +
    scale_fill_discrete('Func.\ngroup') +
    labs(x='COG functional category', y='No. of clusters') +
    theme_bw() +
    coord_flip() 

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %%
# plotting summary: 
p = COG_annot_s %>%
    dt_mutate(Functional_group = stringr::str_wrap(Functional_group, 10)) %>%
    ggplot(aes(COG_cat, perc_abund, fill=Functional_group)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=formatC(N, format='e', digits=0)), hjust=-0.1, size=3) +
    scale_y_continuous(limits=c(0, 20)) +
    scale_fill_discrete('Func.\ngroup') +
    labs(x='COG functional category', y='% of all clusters') +
    theme_bw() +
    coord_flip() 

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# #### Grouped by taxonomy

# %%
# summarizing
COG_annot_s = COG_annot %>%
    dt_distinct(seqid, COG_cat, Functional_group, Domain, Phylum) %>%
    dt_mutate(Domain = ifelse(Domain == '', 'unknown', Domain)) %>%
    dt_summarize(N = n_distinct(seqid), 
                 by=list(COG_cat, Functional_group, Domain, Phylum)) %>%
    dt_mutate(perc_abund = N / total_clusts * 100) %>%
    dt_mutate(n_per_phylum = sum(N), by=list(Domain, Phylum))

COG_annot_s
# Out:
#      COG_cat Functional_group                 Domain   Phylum
# 1    G       Metabolism                       Bacteria Proteobacteria
# 2    M       Cellular processes and signaling Bacteria Proteobacteria
# ⋮    ⋮       ⋮                                ⋮        ⋮
# 2788 W       Cellular processes and signaling Bacteria Deferribacteres
# 2789 E       Metabolism                       Bacteria Candidatus Azambacteria
#      N      perc_abund   n_per_phylum
# 1    673598 0.7162374    11394789
# 2    940045 0.9995508    11394789
# ⋮    ⋮      ⋮            ⋮
# 2788 1      1.063301e-06 104305
# 2789 1      1.063301e-06    107

# %%
# plotting summary by domain
p = COG_annot_s %>%
    dt_filter(n_per_phylum >= 5000) %>%
    dt_mutate(Functional_group = stringr::str_wrap(Functional_group, 10),
              Phylum = reorder(Phylum, n_per_phylum)) %>%
    ggplot(aes(COG_cat, Phylum, size=N, color=Functional_group)) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.5, shape='O') +
    scale_color_discrete('Func.\ngroup') +
    scale_size_continuous('No. of clusters', range=c(0.5, 5)) +
    labs(x='COG functional category', y='No. of genes') +
    theme_bw()

p.dims(6.5,4.5)
plot(p)
# Out:
# plot without title

# %%
# plotting summary: 
p = COG_annot_s %>%
    dt_filter(n_per_phylum >= 200000) %>%
    dt_mutate(Functional_group = stringr::str_wrap(Functional_group, 10),
              Phylum = reorder(Phylum, -n_per_phylum)) %>%
    ggplot(aes(COG_cat, perc_abund, fill=Functional_group)) +
    geom_bar(stat='identity') +
    #geom_text(aes(label=formatC(N, format='e', digits=0)), hjust=-0.1, size=2.2) +
    #scale_y_continuous(limits=c(0, 20)) +
    scale_fill_discrete('Func.\ngroup') +
    facet_wrap(. ~ Phylum, scales='free') +
    labs(x='COG functional category', y='% of all clusters') +
    theme_bw() +
    theme(
        axis.text.x = element_text(size=7)
    ) 

p.dims(11,6)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ##### Just bacteria

# %%
# summarizing
COG_annot_s = COG_annot %>%
    dt_distinct(seqid, COG_cat, Functional_group, Domain, Phylum) %>%
    dt_filter(Domain == 'Bacteria') %>%
    dt_summarize(N = n_distinct(seqid), 
                 by=list(COG_cat, Functional_group, Domain, Phylum)) %>%
    dt_mutate(perc_abund = N / total_clusts * 100) %>%
    dt_mutate(n_per_phylum = sum(N), by=list(Domain, Phylum))

COG_annot_s
# Out:
#      COG_cat Functional_group                 Domain   Phylum
# 1    G       Metabolism                       Bacteria Proteobacteria
# 2    M       Cellular processes and signaling Bacteria Proteobacteria
# ⋮    ⋮       ⋮                                ⋮        ⋮
# 2482 W       Cellular processes and signaling Bacteria Deferribacteres
# 2483 E       Metabolism                       Bacteria Candidatus Azambacteria
#      N      perc_abund   n_per_phylum
# 1    673598 0.7162374    11394789
# 2    940045 0.9995508    11394789
# ⋮    ⋮      ⋮            ⋮
# 2482 1      1.063301e-06 104305
# 2483 1      1.063301e-06    107

# %%
# plotting summary by domain
p = COG_annot_s %>%
    dt_filter(n_per_phylum >= 200000) %>%
    dt_mutate(Functional_group = ifelse(Functional_group == 'Poorly characterized',
                                        'P', Functional_group),
              Functional_group = stringr::str_wrap(Functional_group, 10)) %>%
    ggplot(aes(COG_cat, N, fill=Phylum)) +
    geom_bar(stat='identity') +
    scale_fill_discrete('Phylum') +
    facet_grid(. ~ Functional_group, scales='free_x', space='free_x') +
    labs(x='COG functional category', y='No. of clusters') +
    theme_bw() +
    theme(
        panel.spacing = unit(0.1, "lines"),
        legend.title=element_text(size=10)
    ) +
    guides(fill = guide_legend(override.aes = list(size=2)))

p.dims(6,3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ##### Just Archaea

# %%
# summarizing
COG_annot_s = COG_annot %>%
    dt_distinct(seqid, COG_cat, Functional_group, Domain, Phylum) %>%
    dt_filter(Domain == 'Archaea') %>%
    dt_summarize(N = n_distinct(seqid), 
                 by=list(COG_cat, Functional_group, Domain, Phylum)) %>%
    dt_mutate(perc_abund = N / total_clusts * 100) %>%
    dt_mutate(n_per_phylum = sum(N), by=list(Domain, Phylum))

COG_annot_s
# Out:
#     COG_cat Functional_group                 Domain  Phylum
# 1   F       Metabolism                       Archaea Euryarchaeota
# 2   C       Metabolism                       Archaea Euryarchaeota
# ⋮   ⋮       ⋮                                ⋮       ⋮
# 276 T       Cellular processes and signaling Archaea Candidatus Diapherotrites
# 277 O       Cellular processes and signaling Archaea Candidatus Lokiarchaeota
#     N     perc_abund   n_per_phylum
# 1   18425 0.01959132   220280
# 2   30637 0.03257635   220280
# ⋮   ⋮     ⋮            ⋮
# 276 1     1.063301e-06 16720
# 277 1     1.063301e-06   332

# %%
# plotting summary by domain
p = COG_annot_s %>%
    dt_filter(n_per_phylum >= 500) %>%
    dt_mutate(Functional_group = ifelse(Functional_group == 'Poorly characterized',
                                        'P', Functional_group),
              Functional_group = stringr::str_wrap(Functional_group, 10)) %>%
    ggplot(aes(COG_cat, N, fill=Phylum)) +
    geom_bar(stat='identity') +
    scale_fill_discrete('Phylum') +
    facet_grid(. ~ Functional_group, scales='free_x', space='free_x') +
    labs(x='COG functional category', y='No. of clusters') +
    theme_bw() +
    theme(
      panel.spacing = unit(0.1, "lines"),
      legend.title=element_text(size=10)
    ) +
    guides(fill = guide_legend(override.aes = list(size=2)))

p.dims(6,3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ##### Jus viruses

# %%
# summarizing
COG_annot_s = COG_annot %>%
    dt_distinct(seqid, COG_cat, Functional_group, Domain, Phylum) %>%
    dt_filter(Domain == 'Viruses') %>%
    dt_summarize(N = n_distinct(seqid), 
                 by=list(COG_cat, Functional_group, Domain, Phylum)) %>%
    dt_mutate(perc_abund = N / total_clusts * 100) %>%
    dt_mutate(n_per_phylum = sum(N), by=list(Domain, Phylum))

COG_annot_s
# Out:
#    COG_cat Functional_group                   Domain  Phylum     N
# 1  S       Poorly characterized               Viruses unknown    223034
# 2  L       Information storage and processing Viruses unknown     32946
# ⋮  ⋮       ⋮                                  ⋮       ⋮          ⋮
# 28 L       Information storage and processing Viruses uc_Viruses 3
# 29 T       Cellular processes and signaling   Viruses uc_Viruses 1
#    perc_abund   n_per_phylum
# 1  0.23715227   290074
# 2  0.03503151   290074
# ⋮  ⋮            ⋮
# 28 3.189903e-06 47
# 29 1.063301e-06 47

# %%
# plotting summary by domain
p = COG_annot_s %>%
    dt_mutate(Phylum = ifelse(Phylum == 'uc_Viruses', 'unknown', Phylum),
              Functional_group = ifelse(Functional_group == 'Poorly characterized',
                                        'P', Functional_group),
              Functional_group = stringr::str_wrap(Functional_group, 10),
              Phylum = reorder(Phylum, n_per_phylum)) %>%
    ggplot(aes(COG_cat, N, fill=Phylum)) +
    geom_bar(stat='identity') +
    scale_fill_discrete('Phylum') +
    facet_grid(. ~ Functional_group, scales='free_x', space='free_x') +
    labs(x='COG functional category', y='No. of clusters') +
    theme_bw() +
    theme(
      panel.spacing = unit(0.1, "lines")
    )

p.dims(6,3)
plot(p)
# Out:
# plot without title

# %%
# clearing memory
rm(COG_annot)
rm(COG_annot_s)
gc()
# Out:
#        used       (Mb)    gc trigger  (Mb)     max used    (Mb)
# Ncells  105223423  5619.6   346098786  18483.7   283085429  15118.4
# Vcells 7169680436 54700.4 14809569112 112988.1 14794985305 112876.8

# %% [markdown]
# ## KEGG pathway

# %%
# KEGG pathways
## Reading file
F = file.path(work_dir, 'annotate', 'eggnog-mapper', 'clusters_rep-seqs.emapper.annotations.gz')
cmd = glue::glue('gunzip -c {file}', file=F, header=FALSE) 
#cmd = glue::glue('gunzip -c {file} | head -n 100000', file=F, header=FALSE) 
KEGG_ptw = fread(cmd=cmd, sep='\t') 
colnames(KEGG_ptw) = cols
## Formatting
KEGG_ptw = KEGG_ptw %>%
    dt_select(query_name, KEGG_Pathway) %>%
    dt_mutate(KEGG_Pathway = gsub(',map.+', '', KEGG_Pathway))
## Max pathways per seqid 
max_feats = KEGG_ptw %>%
    dt_mutate(n_feats = stringr::str_count(KEGG_Pathway, ',')) %>%
    dt_pull(n_feats) %>% max
cat('Max pathways per record:', max_feats, '\n')
new_cols = gsub('^', 'X', 1:(max_feats+1))
## separating 
KEGG_Pathway = KEGG_ptw %>%
    dt_separate(KEGG_Pathway, into=new_cols, sep=',') %>%
    dt_pivot_longer(cols=c(-query_name), names_to='X', values_to='KEGG_pathway') %>%
    dt_select(-X) %>%
    dt_filter(!is.na(KEGG_pathway),
              !grepl('^map', KEGG_pathway)) 
KEGG_Pathway
# Out:
# Max pathways per record: 109
# Error in melt.data.table(data = .data, id.vars = id_vars, measure.vars = cols, : negative length vectors are not allowed
# Traceback:
#
# 1. KEGG_ptw %>% dt_separate(KEGG_Pathway, into = new_cols, sep = ",") %>%
#  .     dt_pivot_longer(cols = c(-query_name), names_to = "X", values_to = "KEGG_pathway") %>%
#  .     dt_select(-X) %>% dt_filter(!is.na(KEGG_pathway), !grepl("^map",
#  .     KEGG_pathway))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. dt_pivot_longer(., cols = c(-query_name), names_to = "X", values_to = "KEGG_pathway")
# 9. dt_pivot_longer.tidytable(., cols = c(-query_name), names_to = "X",
#  .     values_to = "KEGG_pathway")
# 10. as_tidytable(melt(data = .data, id.vars = id_vars, measure.vars = cols,
#   .     variable.name = names_to, value.name = values_to, ..., na.rm = values_drop_na,
#   .     variable.factor = FALSE, value.factor = FALSE))
# 11. melt(data = .data, id.vars = id_vars, measure.vars = cols, variable.name = names_to,
#   .     value.name = values_to, ..., na.rm = values_drop_na, variable.factor = FALSE,
#   .     value.factor = FALSE)
# 12. melt.data.table(data = .data, id.vars = id_vars, measure.vars = cols,
#   .     variable.name = names_to, value.name = values_to, ..., na.rm = values_drop_na,
#   .     variable.factor = FALSE, value.factor = FALSE)

# %%
# using kegg ptwy mapping file from humann2 to get pathway hierarchies
ptwy_map_file = '/ebio/abt3_projects/databases_no-backup/humann2/utility_mapping/map_kegg-pwy_name_cat.txt.gz'
cmd = glue::glue('gunzip -c {file}', file=ptwy_map_file)
ptwy_map = fread(cmd=cmd, sep='\t', header=FALSE)
colnames(ptwy_map) = c('KEGG_pathway', 'Level1', 'Level2', 'KEGG_Pathway_Name')
ptwy_map

# %%
# joining
KEGG_Pathway = KEGG_Pathway %>%
    dt_left_join(ptwy_map, by=c('KEGG_pathway')) %>%
    dt_rename(seqid = query_name) %>%
    dt_filter(!is.na(KEGG_Pathway_Name),
              KEGG_Pathway_Name != '')
KEGG_Pathway

# %%
# joining with taxonomy
KEGG_Pathway = KEGG_Pathway %>%
    dt_inner_join(tax, by=c('seqid'))
KEGG_Pathway

# %%
# summary of clusters with annotation
KEGG_Pathway %>% dt_distinct(seqid) %>% dt_pull(seqid) %>% length %>%
    cat('No of clusters with KEGG pathway:', ., '\n')

# %%
# summarizing
KEGG_Pathway_s = KEGG_Pathway %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(Level1, Level2, KEGG_Pathway_Name)) %>%
    dt_filter(Level2 != 'Global and overview maps') 

KEGG_Pathway_s

# %%
# plotting summary
p = KEGG_Pathway_s %>%
    dt_filter(n >= 100000) %>%
    dt_mutate(KEGG_Pathway_Name = reorder(KEGG_Pathway_Name, n)) %>%
    ggplot(aes(KEGG_Pathway_Name, n, fill=Level1)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=n), hjust=-0.1, size=2) +
    #scale_y_continuous(limits=c(0, 150000)) +
    labs(x='KEGG Pathway', y='No. of genes') +  
    theme_bw() +
    theme(
        axis.text.y = element_text(size=8),
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip()

p.dims(7,7.8)
plot(p)

# %%
send_email('http://127.0.0.1:9705/notebooks/notebooks/metagenome/multi-study/09_LLMGAG_all_cluster/01_linclust90/01_linclust-90.ipynb')

# %% [markdown]
# ##### by taxonomy

# %%
# summarizing
KEGG_Pathway_s = KEGG_Pathway %>%
    dt_filter(!is.na(KEGG_Pathway_Name),
              KEGG_Pathway_Name != '') %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(Level1, Level2, KEGG_Pathway_Name, 
                         Domain, Phylum)) %>%
    dt_filter(Level2 != 'Global and overview maps') %>%
    dt_mutate(n_clust_phylum = sum(n), 
              by=list(Domain, Phylum))  %>%
    dt_mutate(n_clust_pathway = sum(n),
              by=list(KEGG_Pathway_Name))

KEGG_Pathway_s
# Out:
#    Level1                               Level2
# 1  Metabolism                           Energy metabolism
# 2  Environmental Information Processing Signal transduction
# ⋮  ⋮                                    ⋮
# 33 Genetic Information Processing       Folding, sorting and degradation
# 34 Cellular Processes                   Cell growth and death
#    KEGG_Pathway_Name         Domain   Phylum         n n_clust_phylum
# 1  Oxidative phosphorylation Bacteria Proteobacteria 1 22
# 2  Two-component system      Bacteria Proteobacteria 2 22
# ⋮  ⋮                         ⋮        ⋮              ⋮ ⋮
# 33 RNA degradation           Bacteria Firmicutes     1 7
# 34 Cell cycle - Caulobacter  Bacteria Firmicutes     1 7
#    n_clust_pathway
# 1  1
# 2  3
# ⋮  ⋮
# 33 1
# 34 1

# %%
# plotting
p = KEGG_Pathway_s %>%
    dt_filter(!Phylum %in% c('unknonwn', 'uc_Bacteria'),
              n_clust_phylum >= 5000,
              n_clust_pathway >= 10000) %>%
    dt_mutate(Level1 = stringr::str_wrap(Level1, 12),
              Phylum = reorder(Phylum, -n_clust_phylum),
              KEGG_Pathway_Name = reorder(KEGG_Pathway_Name, n_clust_pathway)) %>%
    ggplot(aes(Phylum, KEGG_Pathway_Name, size=n, color=Level1)) +
    geom_point(alpha=0.3) +
    geom_point(shape='O', alpha=0.6) +
    scale_size_continuous('No. of clusters') +
    labs(x='Phylum', y='KEGG pathway') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=65, hjust=1),
        axis.text.y = element_text(size=8)
    ) 

p.dims(6,8)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ##### Archaea

# %%
# summarizing
KEGG_Pathway_s = KEGG_Pathway %>%
    dt_filter(Domain == 'Archaea',
              !is.na(KEGG_Pathway_Name),
              KEGG_Pathway_Name != '') %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(Level1, Level2, KEGG_Pathway_Name, 
                         Domain, Phylum)) %>%
    dt_filter(Level2 != 'Global and overview maps') %>%
    dt_mutate(n_clust_phylum = sum(n), 
              by=list(Domain, Phylum))  %>%
    dt_mutate(n_clust_pathway = sum(n),
              by=list(KEGG_Pathway_Name))

KEGG_Pathway_s
# Out:
#   Level1     Level2
# 1 Metabolism Biosynthesis of other secondary metabolites
# 2 Metabolism Carbohydrate metabolism
#   KEGG_Pathway_Name             Domain  Phylum        n n_clust_phylum
# 1 Streptomycin biosynthesis     Archaea Euryarchaeota 1 2
# 2 Inositol phosphate metabolism Archaea Euryarchaeota 1 2
#   n_clust_pathway
# 1 1
# 2 1

# %%
# plotting
p = KEGG_Pathway_s %>%
    dt_filter(!Phylum %in% c('unknown'),
              n_clust_phylum >= 50,
              n_clust_pathway >= 50) %>%
    dt_mutate(Level1 = stringr::str_wrap(Level1, 12),
              Phylum = reorder(Phylum, -n_clust_phylum),
              KEGG_Pathway_Name = reorder(KEGG_Pathway_Name, n_clust_pathway)) %>%
    ggplot(aes(Phylum, KEGG_Pathway_Name, size=n, color=Level1)) +
    geom_point(alpha=0.3) +
    geom_point(shape='O', alpha=0.6) +
    scale_size_continuous('No. of clusters') +
    labs(x='Phylum', y='KEGG pathway') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=65, hjust=1),
        axis.text.y = element_text(size=8)
    ) 

p.dims(6,7)
plot(p)
# Out:
# plot without title

# %%
# clearing memory
rm(KEGG_Pathway)
rm(KEGG_Pathway_s)
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells 1029849 55    1876975   100.3  1876975 100.3
# Vcells 5497668 42   40348491   307.9 48989783 373.8

# %% [markdown]
# ## CAZy

# %%
F = file.path(work_dir, 'annotate', 'eggnog-mapper', 'clusters_rep-seqs.emapper.annotations.gz')
#cmd = glue::glue('gunzip -c {file}', file=F, header=FALSE) 
cmd = glue::glue('gunzip -c {file} | head -n 500000', file=F, header=FALSE) 
CAZy_annot = fread(cmd=cmd, sep='\t') 
colnames(CAZy_annot) = cols
## separate
max_feats = CAZy_annot %>%
    dt_distinct(CAZy) %>% 
    dt_mutate(n_feats = stringr::str_count(CAZy, ',')) %>%
    dt_pull(n_feats) %>% max
new_cols = gsub('^', 'X', 1:(max_feats + 1))
CAZy_annot = CAZy_annot %>%
    dt_select(query_name, CAZy) %>%
    dt_separate(CAZy, into=new_cols, sep=',') %>%
    dt_pivot_longer(cols=c(-query_name), names_to='X', values_to='CAZy') %>%
    dt_filter(!is.na(CAZy)) %>%
    dt_select(-X) %>%
    dt_rename(seqid = query_name) %>%
    dt_mutate(CAZy_module = gsub('[0-9]+$', '', CAZy),
              CAZy = gsub('^([^0-9]+)([0-9])$', '\\10\\2', CAZy),
              CAZy = gsub('^([^0-9]+)([0-9][0-9])$', '\\10\\2', CAZy))
CAZy_annot
# Out:
#       seqid                            CAZy  CAZy_module
# 1     d46f08285b62406bbf036457f3f963f6 GT005 GT
# 2     57f247173da54192ba29bc43947cf77e GT004 GT
# ⋮     ⋮                                ⋮     ⋮
# 18995 b0ebc4db3da843d18b5190ad44bf89e6 GH009 GH
# 18996 e45b5ce0e1da442cbffee4954f977145 GH009 GH

# %%
# joining with taxonomy
CAZy_annot = CAZy_annot %>%
    dt_inner_join(tax, by=c('seqid')) %>%
    dt_filter(!is.na(CAZy))
CAZy_annot
# Out:
#   seqid                            CAZy  CAZy_module Domain   Kingdom
# 1 c5be9bffb4bc4e4f9f06b5a8d8afb81e GT002 GT          Bacteria unknown
# 2 c5be9bffb4bc4e4f9f06b5a8d8afb81e GT004 GT          Bacteria unknown
# ⋮ ⋮                                ⋮     ⋮           ⋮        ⋮
# 6 0727682a805640cab301f33d145709bd GH013 GH          Bacteria unknown
# 7 19774ac2b89a47d5a4298d30cbe59430 GT051 GT          Bacteria unknown
#   Phylum         Class               Order              Family
# 1 Proteobacteria Gammaproteobacteria Pseudomonadales    Moraxellaceae
# 2 Proteobacteria Gammaproteobacteria Pseudomonadales    Moraxellaceae
# ⋮ ⋮              ⋮                   ⋮                  ⋮
# 6 Firmicutes     Clostridia          Clostridiales      Lachnospiraceae
# 7 Actinobacteria Actinobacteria      Actinopolysporales Actinopolysporaceae
#   Genus           Species
# 1 Acinetobacter   Acinetobacter sp. ANC 3903
# 2 Acinetobacter   Acinetobacter sp. ANC 3903
# ⋮ ⋮               ⋮
# 6 Roseburia       Roseburia inulinivorans
# 7 Actinopolyspora Actinopolyspora xinjiangensis

# %%
CAZy_annot %>% dt_distinct(seqid) %>% dt_pull(seqid) %>% length %>%
    cat('Number of CAZy gene clusters:', ., '\n')
# Out:
# Number of CAZy gene clusters: 5

# %%
# summarizing
CAZy_annot_s = CAZy_annot %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(CAZy_module, CAZy)) %>%
    dt_mutate(n_clust_fam = sum(n),
              by=list(CAZy))

CAZy_annot_s
# Out:
#   CAZy_module CAZy  n n_clust_fam
# 1 GT          GT002 1 1
# 2 GT          GT004 1 1
# ⋮ ⋮           ⋮     ⋮ ⋮
# 6 GH          GH013 1 1
# 7 GT          GT051 1 1

# %%
# plotting
p = CAZy_annot_s %>%
    dt_filter(n_clust_fam >= 100) %>%
    dt_mutate(CAZy = reorder(CAZy, n_clust_fam)) %>%
    ggplot(aes(CAZy, n, fill=CAZy_module)) +
    geom_bar(stat='identity') +
    geom_text(aes(label=n), hjust=-0.1, size=2.5) +
    scale_fill_discrete('CAZy\nmodule') +
    scale_y_continuous(limits=c(0, 12000)) +
    labs(x='CAZy family', y='No. of clusters') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=65, hjust=1),
        axis.text.y = element_text(size=8)
    ) +
    coord_flip()

p.dims(4,7)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ##### By taxonomy

# %%
# summarizing
CAZy_annot_s = CAZy_annot %>%
    dt_summarize(n = n_distinct(seqid), 
                 by=list(CAZy_module, CAZy, 
                         Domain, Phylum)) %>%
    dt_mutate(n_clust_phylum = sum(n), 
              by=list(Domain, Phylum))  %>%
    dt_mutate(n_clust_fam = sum(n),
              by=list(CAZy))

CAZy_annot_s
# Out:
#   CAZy_module CAZy  Domain   Phylum         n n_clust_phylum n_clust_fam
# 1 GT          GT002 Bacteria Proteobacteria 1 4              1
# 2 GT          GT004 Bacteria Proteobacteria 1 4              1
# ⋮ ⋮           ⋮     ⋮        ⋮              ⋮ ⋮              ⋮
# 6 GH          GH013 Bacteria Firmicutes     1 2              1
# 7 GT          GT051 Bacteria Actinobacteria 1 1              1

# %%
# plotting
p = CAZy_annot_s %>%
    dt_filter(!Phylum %in% c('unknown', 'uc_Bacteria'),
              n_clust_phylum >= 100,
              n_clust_fam >= 100) %>%
    dt_mutate(Phylum = reorder(Phylum, -n_clust_phylum),
              CAZy = reorder(CAZy, n_clust_fam)) %>%
    ggplot(aes(Phylum, CAZy, size=n, color=CAZy_module)) +
    geom_point(alpha=0.3) +
    geom_point(shape='O', alpha=0.6) +
    scale_size_continuous('No. of\nclusters') +
    scale_color_discrete('CAZy\nmodule') +
    labs(x='Phylum', y='CAZy family') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=65, hjust=1),
        axis.text.y = element_text(size=8)
    ) 

p.dims(4,7.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Humann2 db genes

# %%
# gene IDs
F = file.path(work_dir, 'humann2_db', 'clusters_rep-seqs_annot-index.tsv')

hm2 = fread(F, sep='\t', header=TRUE) %>%
    dt_separate(new_name, c('UniRefID', 'Gene_length', 'Taxonomy'), sep='\\|') %>%
    dt_separate(Taxonomy, c('Genus', 'Species'), sep='\\.s__') %>%
    dt_separate(Species, c('Species', 'TaxID'), sep='__taxID') %>%
    dt_mutate(Genus = gsub('^g__', '', Genus))

hm2
# Out:
#          original_name                    UniRefID        Gene_length
# 1        2a2cefdec88e4aa8abfc87c17023aac1 UniRef50_F0G6T9 92
# 2        da4e86de241540dabc07a79bab4d3299 UniRef50_G5LL88 119
# ⋮        ⋮                                ⋮               ⋮
# 23823219 f4af4646fc3d49af99c74815f4a604a7 UniRef50_K1TZ48 86
# 23823220 a1b4b2d2e36f4749b4c748d47862d48b UniRef50_P00803 288
#          Genus             TaxID
# 1        unclassified      1798258
# 2        Acidimicrobiaceae 525909
# ⋮        ⋮                 ⋮
# 23823219 Ruminococcaceae   853
# 23823220 Cordycipitaceae   1245745

# %%
# checking overlap
overlap(hm2 %>% dt_distinct(original_name) %>% dt_pull(original_name),
        tax %>% dt_distinct(seqid) %>% dt_pull(seqid))
# Out:
# intersect(x,y): 21498123
# setdiff(x,y): 2325097
# setdiff(y,x): 82731085
# union(x,y): 106554305

# %%
# adding taxonomy
hm2 = hm2 %>%
    dt_rename('seqid' = original_name) %>%
    dt_left_join(tax , by=c('seqid'))

hm2
# Out:
#          seqid                            UniRefID        Gene_length
# 1        2a2cefdec88e4aa8abfc87c17023aac1 UniRef50_F0G6T9 92
# 2        da4e86de241540dabc07a79bab4d3299 UniRef50_G5LL88 119
# ⋮        ⋮                                ⋮               ⋮
# 23823219 f4af4646fc3d49af99c74815f4a604a7 UniRef50_K1TZ48 86
# 23823220 a1b4b2d2e36f4749b4c748d47862d48b UniRef50_P00803 288
#          Genus            TaxID   Domain   Kingdom Phylum
# 1        unknown          1798258 Bacteria unknown Proteobacteria
# 2        Acidimicrobium   525909  Bacteria unknown Actinobacteria
# ⋮        ⋮                ⋮       ⋮        ⋮       ⋮
# 23823219 Faecalibacterium 853     Bacteria unknown Firmicutes
# 23823220 NA               1245745 NA       NA      NA
#          Class              Order            Family
# 1        Betaproteobacteria Nitrosomonadales unknown
# 2        Acidimicrobiia     Acidimicrobiales Acidimicrobiaceae
# ⋮        ⋮                  ⋮                ⋮
# 23823219 Clostridia         Clostridiales    Ruminococcaceae
# 23823220 NA                 NA               NA
#          Species
# 1        Gallionellales bacterium RIFOXYB12_FULL_54_9
# 2        Acidimicrobium ferrooxidans
# ⋮        ⋮
# 23823219 Faecalibacterium prausnitzii
# 23823220 NA

# %% [markdown]
# ### Summary

# %%
# number of unique UniRef IDs
hm2 %>% dt_distinct(UniRefID) %>% dt_pull(UniRefID) %>% length %>%
    cat('Number of IDs:', ., '\n')
# Out:
# Number of IDs: 738810

# %%
# duplicate UniRef IDs
df.dims(20)
hm2 %>%
    dt_count(UniRefID) %>%
    dt_arrange(-N) %>%
    dt_slice_head(n=20)
df.dims()
# Out:
#    UniRefID        N
# 1  UniRef50_G7PZX1 20199
# 2  UniRef50_G7PJK4  9898
# 3  UniRef50_R5SAJ6  9127
# 4  UniRef50_G7P3W5  8798
# 5  UniRef50_R6YUP4  8670
# 6  UniRef50_R5NSN2  8335
# 7  UniRef50_W4PGJ5  7457
# 8  UniRef50_L7MAZ2  7431
# 9  UniRef50_E3YX49  7320
# 10 UniRef50_R6HKQ6  6989
# 11 UniRef50_J9GJH2  6846
# 12 UniRef50_D4KIW9  6502
# 13 UniRef50_G7P766  6496
# 14 UniRef50_L8DWL8  6468
# 15 UniRef50_J9GHM4  6431
# 16 UniRef50_T9WNI3  6259
# 17 UniRef50_G4C7G3  6143
# 18 UniRef50_F2ILQ6  5912
# 19 UniRef50_A8UZ55  5857
# 20 UniRef50_H1Y9C1  5616

# %% [markdown]
# #### By taxonomy

# %%
# number of UniRefIDs
hm2_s = hm2 %>%
    dt_summarize(n = n_distinct(seqid), by=list(Domain))

p = hm2_s %>%
    dt_filter(n >= 1000) %>%
    dt_mutate(Domain = Domain %>% reorder(n)) %>%
    ggplot(aes(Domain, n)) +
    geom_bar(stat='identity', position='dodge') +
    scale_y_log10() +
    labs(y='No. of genes') +
    theme_bw() 

p.dims(5,2.5)
plot(p)
# Out:
# plot without title

# %%
# number of UniRefIDs
hm2_s = hm2 %>%
    dt_summarize(n = n_distinct(seqid), by=list(Domain, Phylum)) 

p = hm2_s %>%
    dt_filter(n >= 1000,
              !is.na(Domain),
              Domain != 'unknown',
              !Phylum %in% c('unknown', 'uc_Bacteria')) %>%
    dt_mutate(Phylum = Phylum %>% reorder(n)) %>%
    ggplot(aes(Phylum, n, fill=Domain)) +
    geom_bar(stat='identity', position='dodge') +
    scale_y_log10() +
    coord_flip() +
    labs(y='No. of clusters') +
    theme_bw() +
    theme(
        axis.text.y = element_text(size=9)
    )
    
p.dims(4.5,6)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/tidyverse/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] LeyLabRMisc_0.1.3 doParallel_1.0.15 iterators_1.0.12  foreach_1.4.7
#  [5] tidytable_0.3.2   dtplyr_1.0.0      data.table_1.12.8 ggplot2_3.2.1
#  [9] tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.3       plyr_1.8.5       cellranger_1.1.0 pillar_1.4.3
#  [5] compiler_3.6.2   base64enc_0.1-3  tools_3.6.2      zeallot_0.1.0
#  [9] digest_0.6.23    uuid_0.1-2       jsonlite_1.6     evaluate_0.14
# [13] tibble_2.1.3     lifecycle_0.1.0  gtable_0.3.0     pkgconfig_2.0.3
# [17] rlang_0.4.2      IRdisplay_0.7.0  IRkernel_1.1     stringr_1.4.0
# [21] repr_1.0.2       withr_2.1.2      vctrs_0.2.1      grid_3.6.2
# [25] tidyselect_0.2.5 glue_1.3.1       R6_2.4.1         readxl_1.3.1
# [29] pbdZMQ_0.3-3     reshape2_1.4.3   farver_2.0.2     purrr_0.3.3
# [33] magrittr_1.5     codetools_0.2-16 backports_1.1.5  scales_1.1.0
# [37] htmltools_0.4.0  assertthat_0.2.1 colorspace_1.4-1 labeling_0.3
# [41] stringi_1.4.5    lazyeval_0.2.2   munsell_0.5.0    crayon_1.3.4
