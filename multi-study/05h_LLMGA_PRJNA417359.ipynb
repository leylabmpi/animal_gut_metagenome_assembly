# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#LLMGA" data-toc-modified-id="LLMGA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>LLMGA</a></span><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Subsampling-samples" data-toc-modified-id="Subsampling-samples-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Subsampling samples</a></span></li><li><span><a href="#config" data-toc-modified-id="config-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>config</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Run</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#No.-of-genomes" data-toc-modified-id="No.-of-genomes-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>No. of genomes</a></span></li><li><span><a href="#CheckM" data-toc-modified-id="CheckM-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>CheckM</a></span></li><li><span><a href="#Taxonomy" data-toc-modified-id="Taxonomy-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Taxonomy</a></span><ul class="toc-item"><li><span><a href="#Taxonomic-novelty" data-toc-modified-id="Taxonomic-novelty-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Taxonomic novelty</a></span></li><li><span><a href="#Quality-~-taxonomy" data-toc-modified-id="Quality-~-taxonomy-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Quality ~ taxonomy</a></span></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * running `LLMGA` on metagenome datasets
# * studyID = PRJNA417359
#   * host = chicken

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/'
tmp_out_dir = '/ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/'
pipeline_dir = '/ebio/abt3_projects/methanogen_host_evo/bin/llmga-find-refs/'

studyID = 'PRJNA417359'
threads = 24

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
set.seed(8304)

source('/ebio/abt3_projects/Georg_animal_feces/code/misc_r_functions/init.R')

# %% [markdown]
# # LLMGA

# %% [markdown]
# ## Setup

# %%
out_dir = file.path(tmp_out_dir, studyID) 
make_dir(out_dir)
out_dir = file.path(out_dir, 'LLMGA')
make_dir(out_dir)
# Out:
# Created directory: /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359
# Created directory: /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA

# %%
ref_genomes = file.path(work_dir, studyID, 'LLMGA-find-refs/references/ref_genomes.fna')
cat(ref_genomes)
# Out:
# /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects//PRJNA417359/LLMGA-find-refs/references/ref_genomes.fna

# %% [markdown]
# ## Subsampling samples

# %%
F = file.path(work_dir, studyID, 'LLMGQC/final/samples.txt')
samps = read.delim(F, sep='\t')
samps %>% dfhead
# Out:
# [1] 130   4
#   Sample
# 1 MBJMR04201
# 2 LHCFC01400
# 3 DHKFI23503
#   Read1
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/MBJMR04201/R1_final.fq.gz
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/LHCFC01400/R1_final.fq.gz
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DHKFI23503/R1_final.fq.gz
#   Read2
# 1 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/MBJMR04201/R2_final.fq.gz
# 2 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/LHCFC01400/R2_final.fq.gz
# 3 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DHKFI23503/R2_final.fq.gz
#   Notes
# 1 NA
# 2 NA
# 3 NA

# %%
# subsampling
samps = samps %>%
    sample_n(100)

samps %>% dfhead
# Out:
# [1] 100   4
#    Sample
# 57 DHCFD07801
# 45 DGYMI06202
# 69 DSLMC04102
#    Read1
# 57 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DHCFD07801/R1_final.fq.gz
# 45 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DGYMI06202/R1_final.fq.gz
# 69 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DSLMC04102/R1_final.fq.gz
#    Read2
# 57 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DHCFD07801/R2_final.fq.gz
# 45 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DGYMI06202/R2_final.fq.gz
# 69 /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGQC/final/DSLMC04102/R2_final.fq.gz
#    Notes
# 57 NA
# 45 NA
# 69 NA

# %%
F = file.path(out_dir, 'samples_n100.txt')
write.table(samps, F, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', F, '\n')
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/samples_n100.txt

# %% [markdown]
# ## config

# %%
cat_file(file.path(out_dir, 'config.yaml'))
# Out:
# #-- I/O --#
# # table with sample --> read_file information
# samples_file: /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/PRJNA417359/LLMGA/samples_n100.txt
#
# # output location
# output_dir: /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/PRJNA417359/LLMGA/
#
# #-- reference genome(s) for metacompass --#
# metacompass_ref: /ebio/abt3_projects/Georg_animal_feces/data/metagenome/multi-study/BioProjects/PRJNA417359/LLMGA-find-refs/references/ref_genomes.fna
#
# #-- database --#
# checkM_data: /ebio/abt3_projects/databases_no-backup/checkM/
# sourmash_db: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.sbt.json
# sourmash_lca_db: /ebio/abt3_projects/databases_no-backup/sourmash/v2/genbank-k31.lca.json.gz
# gtdbtk_db: /ebio/abt3_projects/databases_no-backup/GTDB/release89/db_info.md
#
# #-- re-running --#
# # use this to prevent re-running the assembly steps if you just need to rerun post-assembly steps
# skip_assembly: False
#
# #-- software parameters --#
# # Notes:
# ## Use "Skip" to skip any step. If no params, just use ""
# ## Note: You must skip either metacompass_megahit or metacompass_metaspades (or both)
# ## Note: for the *_batches params, the number must be <= the number of MAGs
# params:
#   subsample_reads: 10000000                       # number of read pairs to subsample
#   fastqc_on_raw: ""
#   # metacompass
#   ## ref-based assembly; use "Skip" to skip the ref-based assembly
#   metacompass: ""
#   metacompass_buildcontig: --pickref breadth --mincov 3 -l 500 -n T -b F -u F
#   ## de-novo assembly; use "Skip" to skip the de-novo assembly
#   metacompass_metaspades: -k auto --only-assembler
#   metacompass_megahit: Skip       # eg., (--min-count 3 --min-contig-len 500 --presets meta-sensitive)
#   ## contig length cutoff
#   metacompass_min_contig_len: 1500            # min contig length retained
#   metacompass_derep_contigs: minidentity=100 minscaf=500 minoverlappercent=95
#   # co-assembly
#   ## normalization/subsampling/dereplication
#   bbnorm_metacompass_unmapped: Skip            # eg., (target=100 k=31 minkmers=15 prefilter=t passes=1)
#   subsample_combined: Skip                     # max number of read pairs to use for co-assembly (eg., 10000000)
#   bbnorm_metacompass_unmapped_combined: Skip   # eg., (target=100 k=31 minkmers=15 prefilter=t passes=1)
#   ## co-assembly (default => Skipped)
#   coassemble_metaspades_hybrid: Skip           # eg., (-k auto --only-assembler)
#   # combined, final contigs
#   combine_all_contigs: Skip                    # 'Skip' will cause all samples to be binned seperately
#   metaquast: --max-ref-number 0                # job run on rick to use internet if `--max-ref-number` > 0
#   contig_rename: minscaf=1500                  # minscaf = scaffold length cutoff
#   cut_up_fasta: Skip                           # cutting long contigs for possibly better binning (eg., -c 20000 -o 0)
#   # contig binning
#   ## mapping
#   samtools: -q 0                               # -q = MAPQ cutoff
#   bam_to_depth: --percentIdentity 97
#   ## maxbin2 (2 different binning parameters used)
#   maxbin2_low_prob: -min_contig_length 1500 -markerset 40  -prob_threshold 0.6
#   maxbin2_high_prob: -min_contig_length 1500 -markerset 40  -prob_threshold 0.8
#   ### metabat (2 different binning parameters used)
#   metabat2_low_PE: --minContig 1500 --minCV 1 --minCVSum 1  --maxP 92 --maxEdges 150
#   metabat2_high_PE: --minContig 1500 --minCV 1 --minCVSum 1 --maxP 97 --maxEdges 500
#   ### vamb
#   vamb: Skip #-m 1500 -s 0                           # -s = MAPQ_score_cutoff
#   # bin refinement/assessment
#   ## selecting the 'best' bins from all binning methods
#   das_tool: --search_engine diamond
#   ## bin assessment
#   bin_batches: 30                               # process MAGs in batches (increase if medium to large dataset)
#   checkm: --tab_table
#   sourmash_compute: --scaled 10000 -k 31
#   sourmash_gather: -k 31 --dna
#   fastani_batches: 30                           # process MAGs in batches (increase if medium to large dataset)
#   fastani: --fragLen 1000 --minFrag 50 -k 16
#   gtdbtk_classify_wf: --min_perc_aa 10
#   drep: -comp 50 -con 5 -sa 99
#   ### anivo; use "Skip" on anvio_gen_contigs_db to skip all of anvio
#   anvio_gen_contigs_db: Skip                 # eg., (--skip-mindful-splitting --kmer-size 4)
#   anvio_run_ncbi_cogs: --cog-data-dir /ebio/abt3_projects/databases_no-backup/anvio_v4/
#   anvio_centrifuge: -x /ebio/abt3_projects/databases_no-backup/centrifuge/p+h+v
#   anvio_profile: --min-mean-coverage 0 --min-contig-length 1500 --cluster-contigs
#   anvio_merge: -S coassembly_contigs --skip-concoct-binning
#   anvio_interactive_script: -P 8080 -C DAS_Tool
#
# #-- snakemake pipeline --#
# # your username will be added automatically to the `temp_folder` path
# pipeline:
#   bwlimit: 100m                            # rsync bwlimit
#   snakemake_folder: ./
#   script_folder: bin/scripts/
#   temp_folder: /tmp/global/

# %% [markdown]
# ## Run

# %% [markdown]
# ```
# (snakemake_dev) @ rick:/ebio/abt3_projects/vadinCA11/bin/llmga
# $ screen -L -S llmga-PRJNA417359 ./snakemake_sge.sh /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/PRJNA417359/LLMGA/config.yaml cluster.json /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl/PRJNA417359/LLMGA/SGE_log/ 20
# ```

# %%
pipelineInfo('/ebio/abt3_projects/methanogen_host_evo/bin/llmga')
# Out:
# LLMGA
# =====
#
# Ley Lab Metagenome Aseembly (LLMGA)
#
# * Version: 0.7.0
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/anvio.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::centrifuge
# - bioconda::anvio>=5.1.0
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/bbmap.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::bbmap=37.90
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/bowtie2.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::samtools
# - bioconda::bowtie2
# - bioconda::bedtools
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/checkm.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - python=2
# - pigz
# - bioconda::prodigal
# - bioconda::pplacer
# - bioconda::checkm-genome
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/concoct.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::pysam=0.14.1
# - bioconda::concoct=0.4.0
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/coverage.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - conda-forge::biopython
# - bioconda::samtools
# - bioconda::bbmap
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/das_tool.yaml <==
# channels:
# - conda-forge
# - bioconda
# - r
# dependencies:
# - pigz
# - bioconda::das_tool
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/drep.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::mash
# - bioconda::checkm-genome
# - bioconda::drep
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/fastani.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::fastani
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/fastqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::fastqc
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/gtdbtk.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::gtdbtk
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/hadley.yaml <==
# channels:
# - conda-forge
# dependencies:
# - conda-forge::r-ape
# - conda-forge::r-dplyr
# - conda-forge::r-tidyr
# - conda-forge::r-ggplot2
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/maxbin2.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::perl-lwp-simple
# - bioconda::maxbin2=2.2.4
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/megahit.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::megahit=1.1.3
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/metabat2.yaml <==
# channels:
# - BioBuilds
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - python=2.7
# - BioBuilds::boost>=1.55.0
# - scons>=2.1.0
# - zlib>=1.2.4
# - BioBuilds::binutils>=2.2.2
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/metacompass.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz=2.3.4
# - bioconda::seqtk
# - bioconda::bioawk
# - bioconda::blast=2.7.1
# - bioconda::meryl=2013
# - bioconda::samtools=1.8
# - bioconda::megahit=1.1.3
# - bioconda::spades=3.12.0
# - bioconda::pilon=1.22=1
# - bioconda::bowtie2=2.3.4.1
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/multiqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::multiqc
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/quast.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - python=2.7
# - bioconda::quast
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/seqtk.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::seqtk
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/sourmash.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::sourmash
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/spades.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::spades=3.12.0
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/datatable.yaml <==
# channels:
# - conda-forge
# dependencies:
# - conda-forge::r-argparse
# - conda-forge::r-data.table
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/kraken2.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::kraken2
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/krakenuniq.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::krakenuniq
#
# ==> /ebio/abt3_projects/methanogen_host_evo/bin/llmga/bin/envs/vamb.yaml <==
# channels:
# - conda-forge
# - bioconda
# - pytorch
# dependencies:
# - pip
# - pigz
# - python=3
# - cudatoolkit=9.0
# - pytorch::torchvision
# - pytorch::pytorch
# - pip:
#   - https://github.com/jakobnissen/vamb/archive/v2.0.1.zip

# %% [markdown]
# # Summary

# %%
asmbl_dir = out_dir = file.path(tmp_out_dir, studyID, 'LLMGA')

checkm_markers_file = file.path(asmbl_dir, 'checkm', 'markers_qa_summary.tsv')
gtdbtk_bac_sum_file = file.path(asmbl_dir, 'gtdbtk', 'gtdbtk_bac_summary.tsv')
gtdbtk_arc_sum_file = file.path(asmbl_dir, 'gtdbtk', 'gtdbtk_ar_summary.tsv')

bin_dir = file.path(asmbl_dir, 'bin')
das_tool_dir = file.path(asmbl_dir, 'bin_refine', 'DAS_Tool')
drep_dir = file.path(asmbl_dir, 'drep', 'drep')

# %%
# bin genomes
## maxbin2
bin_files = list.files(bin_dir, '*.fasta$', full.names=TRUE, recursive=TRUE)
bin = data.frame(binID = gsub('\\.fasta$', '', basename(bin_files)),
                 fasta = bin_files,
                 binner = bin_files %>% dirname %>% basename,
                 sample = bin_files %>% dirname %>% dirname %>% basename)

## metabat2
bin_files = list.files(bin_dir, '*.fa$', full.names=TRUE, recursive=TRUE)
X = data.frame(binID = gsub('\\.fa$', '', basename(bin_files)),
               fasta = bin_files,
               binner = bin_files %>% dirname %>% basename,
               sample = bin_files %>% dirname %>% dirname %>% basename)

## combine
bin = rbind(bin, X)
X = NULL
bin %>% dfhead
# Out:
# [1] 13392     4
#   binID
# 1 coassemble_contigs.001
# 2 coassemble_contigs.002
# 3 coassemble_contigs.003
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin/CBJMC01400/maxbin2_high_prob/coassemble_contigs.001.fasta
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin/CBJMC01400/maxbin2_high_prob/coassemble_contigs.002.fasta
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin/CBJMC01400/maxbin2_high_prob/coassemble_contigs.003.fasta
#   binner            sample
# 1 maxbin2_high_prob CBJMC01400
# 2 maxbin2_high_prob CBJMC01400
# 3 maxbin2_high_prob CBJMC01400

# %%
# DAS-tool genomes
dastool_files = list.files(das_tool_dir, '*.fa$', full.names=TRUE, recursive=TRUE)

dastool = data.frame(binID = gsub('\\.fa$', '', basename(dastool_files)),
                    fasta = dastool_files)
dastool %>% dfhead
# Out:
# [1] 1528    2
#   binID
# 1 CBJMC01400__maxbin2_high_prob.004.contigs
# 2 CBJMC01400__maxbin2_high_prob.019.contigs
# 3 CBJMC01400__maxbin2_high_prob.029.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/CBJMC01400__maxbin2_high_prob.004.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/CBJMC01400__maxbin2_high_prob.019.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/bin_refine/DAS_Tool/bins_DASTool_bins/CBJMC01400__maxbin2_high_prob.029.contigs.fa

# %%
# drep genome files
P = file.path(drep_dir, 'dereplicated_genomes')
drep_files = list.files(P, '*.fa$', full.names=TRUE)

drep = data.frame(binID = gsub('\\.fa$', '', basename(drep_files)),
                  fasta = drep_files)
drep %>% dfhead
# Out:
# [1] 1235    2
#   binID
# 1 CBJMC01400__maxbin2_high_prob.019.contigs
# 2 CBJMC01400__metabat2_high_PE.029.contigs
# 3 CBJMC01400__metabat2_low_PE.018.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__maxbin2_high_prob.019.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_high_PE.029.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_low_PE.018.contigs.fa

# %%
# checkm info
markers_sum = read.delim(checkm_markers_file, sep='\t')
markers_sum %>% nrow %>% print

drep_j = drep %>%
    inner_join(markers_sum, c('binID'='Bin.Id')) 

drep_j %>% dfhead
# Out:
# [1] 1528
# Warning message:
# “Column `binID`/`Bin.Id` joining factors with different levels, coercing to character vector”
# [1] 1235   30
#   binID
# 1 CBJMC01400__maxbin2_high_prob.019.contigs
# 2 CBJMC01400__metabat2_high_PE.029.contigs
# 3 CBJMC01400__metabat2_low_PE.018.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__maxbin2_high_prob.019.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_high_PE.029.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_low_PE.018.contigs.fa
#   Marker.lineage               X..genomes X..markers X..marker.sets
# 1 o__Clostridiales (UID1212)   172        261        147
# 2 f__Lachnospiraceae (UID1256)  33        333        171
# 3 f__Lachnospiraceae (UID1256)  33        333        171
#   Completeness Contamination Strain.heterogeneity Genome.size..bp. ⋯
# 1 97.96        0.00           0.00                3221046          ⋯
# 2 93.98        4.78          23.53                4668759          ⋯
# 3 94.18        0.88           0.00                2598530          ⋯
#   GC.std..scaffolds...1kbp. Coding.density Translation.table X..predicted.genes
# 1 3.44                      90.28          11                2997
# 2 4.96                      90.77          11                4399
# 3 2.42                      91.19          11                2592
#   X0 X1  X2 X3 X4 X5.
# 1  3 258  0 0  0  0
# 2 29 287 17 0  0  0
# 3 21 310  2 0  0  0

# %%
# gtdb
## bacteria
X = read.delim(gtdbtk_bac_sum_file, sep='\t') %>%
    dplyr::select(-other_related_references.genome_id.species_name.radius.ANI.AF.) %>%
    separate(classification, c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'), sep=';')
X %>% nrow %>% print

if(file.size(gtdbtk_arc_sum_file) > 0){
    Y = read.delim(gtdbtk_arc_sum_file, sep='\t') 
    colnames(Y) = gtdbtk_bac_sum_file %>% read.delim(sep='\t') %>% colnames
    Y = Y %>%
        dplyr::select(-other_related_references.genome_id.species_name.radius.ANI.AF.) %>%
        separate(classification, c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'), sep=';')
    X = rbind(X,Y)
}

## combined
drep_j = drep_j %>%
    left_join(X, c('binID'='user_genome'))

## status
X = Y = NULL
drep_j %>% dfhead
# Out:
# [1] 1528
# Warning message:
# “Column `binID`/`user_genome` joining character vector and factor, coercing into character vector”
# [1] 1235   53
#   binID
# 1 CBJMC01400__maxbin2_high_prob.019.contigs
# 2 CBJMC01400__metabat2_high_PE.029.contigs
# 3 CBJMC01400__metabat2_low_PE.018.contigs
#   fasta
# 1 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__maxbin2_high_prob.019.contigs.fa
# 2 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_high_PE.029.contigs.fa
# 3 /ebio/abt3_projects/databases_no-backup/animal_gut_metagenomes/multi-study_MG-asmbl//PRJNA417359/LLMGA/drep/drep/dereplicated_genomes/CBJMC01400__metabat2_low_PE.018.contigs.fa
#   Marker.lineage               X..genomes X..markers X..marker.sets
# 1 o__Clostridiales (UID1212)   172        261        147
# 2 f__Lachnospiraceae (UID1256)  33        333        171
# 3 f__Lachnospiraceae (UID1256)  33        333        171
#   Completeness Contamination Strain.heterogeneity Genome.size..bp. ⋯
# 1 97.96        0.00           0.00                3221046          ⋯
# 2 93.98        4.78          23.53                4668759          ⋯
# 3 94.18        0.88           0.00                2598530          ⋯
#   closest_placement_taxonomy
# 1 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Gemmiger;s__Gemmiger variabile
# 2 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Faecalicatena;s__Faecalicatena sp002160525
# 3 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Sellimonas;s__Sellimonas sp002161525
#   closest_placement_ani closest_placement_af
# 1 84.51                 0.6
# 2 98.9                  0.82
# 3 99.06                 0.96
#   pplacer_taxonomy
# 1 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Gemmiger;s__
# 2 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Faecalicatena;s__
# 3 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Sellimonas;s__
#   classification_method
# 1 Placement
# 2 ANI/Placement
# 3 ANI/Placement
#   note                                                             aa_percent
# 1 taxonomic classification fully defined by topology               97.98
# 2 topological placement and ANI have congruent species assignments 85.77
# 3 topological placement and ANI have congruent species assignments 89.01
#   translation_table red_value      warnings
# 1 11                0.993583639048 N/A
# 2 11                N/A            N/A
# 3 11                N/A            N/A

# %% [markdown]
# ## No. of genomes

# %%
cat('Number of binned genomes:', bin$fasta %>% unique %>% length)
# Out:
# Number of binned genomes: 13392

# %%
cat('Number of DAS-Tool passed genomes:', dastool$binID %>% unique %>% length)
# Out:
# Number of DAS-Tool passed genomes: 1528

# %%
cat('Number of 99% ANI de-rep genomes:', drep_j$binID %>% unique %>% length)
# Out:
# Number of 99% ANI de-rep genomes: 1235

# %% [markdown]
# ## CheckM

# %%
# checkm stats
p = drep_j %>%
    dplyr::select(binID, Completeness, Contamination) %>%
    gather(Metric, Value, -binID) %>%
    ggplot(aes(Value)) +
    geom_histogram(bins=30) +
    labs(y='No. of MAGs\n(>=99% ANI derep.)') +
    facet_grid(Metric ~ ., scales='free_y') +
    theme_bw()

dims(4,3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Taxonomy

# %%
# summarizing by taxonomy
p = drep_j %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='No. of MAGs\n(>=99% ANI derep.)') +
    theme_bw() 

dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Taxonomic novelty

# %%
# no close ANI matches 
p = drep_j %>%
    unite(Taxonomy, Phylum, Class, sep=';', remove=FALSE) %>%
    mutate(closest_placement_ani = closest_placement_ani %>% as.character,
           closest_placement_ani = ifelse(closest_placement_ani == 'N/A', 
                                          0, closest_placement_ani),
           closest_placement_ani = ifelse(is.na(closest_placement_ani), 
                                          0, closest_placement_ani),
           closest_placement_ani = closest_placement_ani %>% as.Num) %>%
    mutate(has_species_placement = ifelse(closest_placement_ani >= 95,
                                          'ANI >= 95%', 'No match')) %>%
    ggplot(aes(Taxonomy, fill=Phylum)) +
    geom_bar() +
    facet_grid(. ~ has_species_placement) +
    coord_flip() +
    labs(y='Closest placement ANI') +
    theme_bw() 

dims(7,4)
plot(p)
# Out:
# plot without title

# %%
p = drep_j %>%
    filter(Genus == 'g__') %>%
    unite(Taxonomy, Phylum, Class, Order, Family, sep='; ', remove=FALSE) %>%
    mutate(Taxonomy = stringr::str_wrap(Taxonomy, 45),
           Taxonomy = gsub(' ', '', Taxonomy)) %>%
    group_by(Taxonomy, Phylum) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Taxonomy, n, fill=Phylum)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='No. of MAGs lacking a\ngenus-level classification') +
    theme_bw() 

dims(8,6.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Quality ~ taxonomy

# %%
p = drep_j %>%
    unite(Taxonomy, Phylum, Class, sep='; ', remove=FALSE) %>%
    dplyr::select(Taxonomy, Phylum, Completeness, Contamination) %>%
    gather(Metric, Value, -Taxonomy, -Phylum) %>%
    ggplot(aes(Taxonomy, Value, color=Phylum)) +
    geom_boxplot() +
    facet_grid(. ~ Metric, scales='free_x') +
    coord_flip() +
    labs(y='CheckM quality') +
    theme_bw() 

dims(7,4)
plot(p)
# Out:
# plot without title

# %%
# just unclassified at genus/species
p = drep_j %>%
    filter(Genus == 'g__' | Species == 's__') %>%
    unite(Taxonomy, Phylum, Class, sep='; ', remove=FALSE) %>%
    dplyr::select(Taxonomy, Phylum, Completeness, Contamination) %>%
    gather(Metric, Value, -Taxonomy, -Phylum) %>%
    ggplot(aes(Taxonomy, Value, color=Phylum)) +
    geom_boxplot() +
    facet_grid(. ~ Metric, scales='free_x') +
    coord_flip() +
    labs(y='CheckM quality') +
    theme_bw() 

dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
# [1] en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] bindrcpp_0.2.2    data.table_1.11.4 ggplot2_3.0.0     tidyr_0.8.1
# [5] dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.17     pillar_1.2.2     compiler_3.4.1   plyr_1.8.4
#  [5] bindr_0.1.1      base64enc_0.1-3  tools_3.4.1      digest_0.6.15
#  [9] uuid_0.1-2       jsonlite_1.5     evaluate_0.10.1  tibble_1.4.2
# [13] gtable_0.2.0     pkgconfig_2.0.1  rlang_0.2.1      IRdisplay_0.4.4
# [17] IRkernel_0.8.12  repr_0.15.0      withr_2.1.1      stringr_1.3.1
# [21] grid_3.4.1       tidyselect_0.2.4 glue_1.3.0       R6_2.2.2
# [25] pbdZMQ_0.3-2     reshape2_1.4.3   purrr_0.2.4      magrittr_1.5
# [29] scales_0.5.0     htmltools_0.3.6  assertthat_0.2.0 colorspace_1.3-2
# [33] labeling_0.3     stringi_1.2.3    lazyeval_0.2.1   munsell_0.5.0
# [37] crayon_1.3.4
